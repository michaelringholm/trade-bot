# %% [markdown]
# # App Overview

# %%
# 🛠 Imports and logging setup
import logging
import datetime
import pandas as pd
import yfinance as yf
import requests
from bs4 import BeautifulSoup
import datetime
import json
from yfinance import Ticker
from typing import List
from pandas import DataFrame
from datetime import datetime, timezone
from typing import List
from yfinance import Ticker
from tqdm import tqdm
from tqdm.auto import tqdm as with_progress

# %%
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def log(msg, emoji="ℹ️"):
    logging.info(f"{emoji} {msg}")

# %%
# 🌍 OBSOLETE: Define sectors & scrape tickers (placeholder: extend over time)
todays_date = datetime.date.today().strftime("%Y-%m-%d")
log(f"Fetching stock lists for {todays_date}", "📅")

# For demo: hardcode sample tickers (can extend by scraping)
tech_tickers = ["AAPL", "MSFT", "NVDA", "GOOGL", "AMZN"]
renewable_tickers = ["NEE", "ENPH", "PLUG", "FSLR", "SEDG"]
manufacturing_tickers = ["GE", "CAT", "DE", "BA", "HON"]

pruned_tickers = tech_tickers + renewable_tickers + manufacturing_tickers
log(f"Collected {len(pruned_tickers)} tickers (sample universe)", "📊")

universe_df = pd.DataFrame({
    "Ticker": pruned_tickers,
    "Sector": ["Tech"]*len(tech_tickers) + ["Renewable"]*len(renewable_tickers) + ["Manufacturing"]*len(manufacturing_tickers)
})
universe_df

# %% [markdown]
# 📊 Investor Metric Table (with Examples)
# | Metric                      | Short Name        | What it shows                               | Why you care (as an investor)                                   | Example (simple scenario)                                              | Typical Range | Red Flag 🚩        | Green Flag ✅  |
# | --------------------------- | ----------------- | ------------------------------------------- | --------------------------------------------------------------- | ---------------------------------------------------------------------- | ------------- | ------------------ | ------------- |
# | **Dividend Yield**          | Yield %           | Yearly cash payout vs share price           | It’s your “paycheck” for owning the stock.                      | Invest $100k → 5% yield pays you $5k yearly.                           | 2–6%          | >8% often unsafe   | 3–5% steady   |
# | **P/E (Price-to-Earnings)** | Price ÷ Profit    | Price of share vs profit per share          | Tells if stock is cheap or expensive compared to what it earns. | P/E 15 = you pay $15 for each $1 of profit.                            | 10–20         | >30 without growth | 12–18         |
# | **PEG**                     | Price vs Growth   | P/E compared to growth rate                 | Shows if a high price is justified by fast growth.              | Two stocks at P/E 30: one grows 30% (fair), one grows 5% (overpriced). | ~1            | >2 overpaying      | ~1 fair       |
# | **Debt-to-Equity**          | Debt Load         | Debt vs company’s own money                 | High debt makes a company fragile; lenders get paid before you. | $2 debt for each $1 own money = risky.                                 | 0.5–2         | >3 fragile         | <1 safe       |
# | **Net Debt / EBITDA**       | Debt Years        | Debt minus cash vs yearly earnings          | How many years of profit needed to clear debt.                  | Debt $10B, profit $2B = 5 years to pay off.                            | 2–4           | >5 heavy risk      | <2 strong     |
# | **EV/EBITDA**               | Payback Years     | Company’s full price tag vs yearly earnings | How long it takes to “earn back” the company price.             | Company valued $100B, earns $10B/yr → 10 years.                        | 6–10          | >15 overpriced     | 6–8 fair      |
# | **EV/Sales**                | Price vs Sales    | Company’s full price tag vs yearly sales    | Lets you value sales even if no profits.                        | Valued $5B, sales $2B → 2.5× sales.                                    | 1–3           | >5 hype            | <2 reasonable |
# | **ROE (Return on Equity)**  | Profit Efficiency | Profit vs company’s own money               | Shows how well company turns its resources into profit.         | Equity $10B, profit $2B = 20%.                                         | 10–20%        | <5% weak           | >15% strong   |
# | **Current Ratio**           | Liquidity         | Assets vs short-term bills                  | Shows if company can cover near-term bills.                     | $2 assets for each $1 bill due = safe.                                 | 1.0–2.0       | <1 cash crunch     | 1.5–2 cushion |

# %%
# simple in-memory cache { "YYYY-MM-DD": { "TICKER": TickerObj } }
stock_mem_cache: dict[str, dict[str, yf.Ticker]] = {}

# %%
def get_stock(ticker_symbol:str)->Ticker:
    global stock_mem_cache

    todays_date = datetime.today().date().isoformat()  # YYYY-MM-DD
    if todays_date not in stock_mem_cache:
        stock_mem_cache[todays_date] = {}
    if ticker_symbol not in stock_mem_cache[todays_date]:
        #log(f"Stock cache miss for '{ticker_symbol}' with date '{todays_date}'", "⚠️")
        stock_mem_cache[todays_date][ticker_symbol] = yf.Ticker(ticker_symbol)
    return stock_mem_cache[todays_date][ticker_symbol]

# %%
# Clear cache
def clear_cache():
    global stock_mem_cache
    stock_mem_cache = {}

# %%
clear_cache()

# %%
# 🌍 Fetch top 50 live high dividend tickers (via screener + yield filter)
today_str = datetime.today().strftime("%Y-%m-%d")
log(f"Fetching live high dividend stocks for {today_str}", "📅")

import requests, yfinance as yf

gross_ticker_count = 200
scrId = "most_actives"  # wide enough universe
api_url = (
    f"https://query2.finance.yahoo.com/v1/finance/screener/predefined/saved?"
    f"formatted=true&scrIds={scrId}&count={gross_ticker_count}&start=0"
)

resp = requests.get(api_url, headers={"User-Agent": "Mozilla/5.0"})
data = resp.json()
quotes = (
    data.get("finance", {})
        .get("result", [{}])[0]
        .get("quotes", [])
)

log(f"Collected {len(quotes)} tickers from Yahoo screener '{scrId}'", "📊")

# ✅ Filter tickers by dividend yield
high_dividend_tickers = []
yield_floor = 3.0
low_yield_stock_cnt = 0
for quote in with_progress(quotes, desc=f"Searching for high dividend stocks above {yield_floor}%"):
    ticker_symbol = quote.get("symbol")
    if not ticker_symbol:
        continue
    try:
        stock = get_stock(ticker_symbol)
        stock_info = stock.info
        dy = stock_info.get("dividendYield")
        if dy and dy > yield_floor:  # only >3% dividend yield
            high_dividend_tickers.append(ticker_symbol)
            #log(f"{t} passes dividend filter ({dy:.2f}%)", "✅")
        else:
            low_yield_stock_cnt+=1
    except Exception as e:
        log(f"Problem with ticker '{ticker_symbol}'. Exception: {e}", "⚠️")

log(f"Found {len(high_dividend_tickers)} stocks above {yield_floor}%.", "🎯")
log(f"Skipped {low_yield_stock_cnt} stocks as they were below the yield floor of {yield_floor}%.", "⏭️")
pruned_tickers = high_dividend_tickers[:50]  # 🔑 <-- your original flow preserved
log(f"Final selection: {len(pruned_tickers)} high dividend tickers", "📉")

universe_df = pd.DataFrame({
    "Ticker": pruned_tickers,
    "Sector": "High Dividend"
})
# Out:
# 2025-09-26 11:49:07,667 - INFO - 📅 Fetching live high dividend stocks for 2025-09-26
# 2025-09-26 11:49:08,441 - INFO - 📊 Collected 200 tickers from Yahoo screener 'most_actives'
# Searching for high dividend stocks above 3.0%: 100%|██████████| 200/200 [01:25<00:00,  2.33it/s]
# 2025-09-26 11:50:34,415 - INFO - 🎯 Found 46 stocks above 3.0%.
# 2025-09-26 11:50:34,416 - INFO - ⏭️ Skipped 154 stocks as they were below the yield floor of 3.0%.
# 2025-09-26 11:50:34,417 - INFO - 📉 Final selection: 46 high dividend tickers

# %%
# TODO Debug
stock = get_stock("NVDA")

# %%
universe_df

# %%
# TODO: Seems to be obsolete
# 🌍 Fetch tickers from Yahoo screener (generic)
todays_date = datetime.date.today().strftime("%Y-%m-%d")
log(f"Fetching screener results for {todays_date}", "📅")

# You can change scrId here: "day_gainers", "most_actives", "day_losers", etc.
scrId = "day_gainers"

api_url = (
    f"https://query2.finance.yahoo.com/v1/finance/screener/predefined/saved?"
    f"formatted=true&scrIds={scrId}&count=50&start=0"
)

resp = requests.get(api_url, headers={"User-Agent": "Mozilla/5.0"})
log(f"HTTP status code: {resp.status_code}", "🌐")

data = resp.json()
quotes = (
    data.get("finance", {})
        .get("result", [{}])[0]
        .get("quotes", [])
)

log(f"Found {len(quotes)} quotes under screener '{scrId}'", "📑")

high_dividend_tickers = [
    {"Ticker": q.get("symbol"), "Name": q.get("longName", q.get("shortName"))}
    for q in quotes if q.get("symbol")
]

universe_df = pd.DataFrame(high_dividend_tickers)
universe_df["Sector"] = scrId
log(f"Collected {len(universe_df)} tickers from Yahoo screener '{scrId}'", "📊")

universe_df

# %%
data
# Out:
# []

# %%
def calc_current_div_yield(stock: Ticker)->float:
    stock_info = stock.info or {}
    return round((stock_info.get("dividendRate")/stock_info.get("currentPrice"))*100,2)

# %%
def to_pct(raw):
    if raw is None:
        pct = None
    else:
        pct = round(raw * 100, 2) if raw <= 1 else round(raw, 2)
    return pct

# %%
def from_unix_datetime(ts: int):
    """Convert UNIX timestamp (seconds) → UTC timezone-aware datetime."""
    if ts is None:
        return None
    try:
        return datetime.fromtimestamp(int(ts), tz=timezone.utc)
    except Exception:
        return None

# %%
def to_date(unix_ts: int):
    """Convert UNIX timestamp (seconds) → UTC timezone-aware datetime."""
    if unix_ts is None:
        return None
    try:
        return datetime.fromtimestamp(int(unix_ts), tz=timezone.utc).date()
    except Exception:
        return None

# %%
def print_stock_info(stock:Ticker):
    stock_info_json = stock.info or {}
    print(pretty_print_json(stock_info_json))
    print("=======================")
    print(f"\n🔍 {ticker_symbol} — {stock_info_json.get('longName')}")
    #print("dividendYield raw:", stock_info.get("dividendYield"))
    print("displayName:", stock_info_json.get("displayName"))
    print("symbol:", stock_info_json.get("symbol"))
    print("website:", stock_info_json.get("website"))
    print("exchange:", stock_info_json.get("exchange"))
    print("country:", stock_info_json.get("country"))
    print("fiveYearAvgDividendYield:", stock_info_json.get("fiveYearAvgDividendYield"))
    print("dividendRate:", stock_info_json.get("dividendRate")) # Expected
    print("dividendYield:", stock_info_json.get("dividendYield")) # Based on price between previous
    print(f"currentDividendYield:{calc_current_div_yield(stock):.2f}") # Forward Dividend Rate ÷ Current Share Price × 100 %.
    print("lastDividendDate:", to_date(stock_info_json.get("lastDividendDate")))
    print("dividendDate:", to_date(stock_info_json.get("dividendDate")))
    print("exDividendDate:", to_date(stock_info_json.get("exDividendDate")))
    print("lastDividendValue:", stock_info_json.get("lastDividendValue"))
    print("currentPrice:", stock_info_json.get("currentPrice"))
    print("quoteType:", stock_info_json.get("quoteType"))
    print("industry:", stock_info_json.get("industry"))
    #print("sharesOutstanding:", stock_info.get("sharesOutstanding"))
    #print("currency:", stock_info.get("currency"))
    #print("ask:", stock_info.get("ask"))
    #print("askSize:", stock_info.get("askSize"))
    #print("previousClose:", stock_info.get("previousClose"))
    #print("market:", stock_info.get("market"))
    #print("marketCap:", stock_info.get("marketCap"))
    #print("fiftyDayAverage:", stock_info.get("fiftyDayAverage"))
    #print("fiftyTwoWeekHigh:", stock_info.get("fiftyTwoWeekHigh"))
    #print("fiftyTwoWeekLow:", stock_info.get("fiftyTwoWeekLow"))
    #print("boardRisk:", stock_info.get("boardRisk"))

# %%
def to_millions(amount)->float:
    modified_amount = None
    if(amount is not None and amount):
        if(amount > 1000000): modified_amount = round(amount / 1000000, ndigits=2)
        else: modified_amount = round(amount, ndigits=2)
    log(f"called to millions with amount={amount} and type '{type(amount)}'. Returning amount={modified_amount}")
    return round(modified_amount, ndigits=2)

# %%
def stocks_to_pd(stocks: List[Ticker])->DataFrame:
    rows = []
    #for stock in stocks:
    for stock in tqdm(stocks, desc="Converting stock list to DataFrame"):
        #stock = yf.Ticker(t)
        stock_info_json = stock.info or {}
        rows.append({
            "🔍": stock_info_json.get("longName"),
            "displayName": stock_info_json.get("displayName"),
            "symbol": stock_info_json.get("symbol"),
            "website": stock_info_json.get("website"),
            "exchange": stock_info_json.get("exchange"),
            "country": stock_info_json.get("country"),
            "fiveYearAvgDividendYield": stock_info_json.get("fiveYearAvgDividendYield"),
            "dividendRate": stock_info_json.get("dividendRate"),
            "dividendYield": stock_info_json.get("dividendYield"),
            "currentDividendYield": calc_current_div_yield(stock),
            "lastDividendDate": to_date(stock_info_json.get("lastDividendDate")),
            "dividendDate": to_date(stock_info_json.get("dividendDate")),
            "exDividendDate": to_date(stock_info_json.get("exDividendDate")),
            "lastDividendValue": stock_info_json.get("lastDividendValue"),
            "currentPrice": stock_info_json.get("currentPrice"),
            "quoteType": stock_info_json.get("quoteType"),
            "industry": stock_info_json.get("industry"),
            "sharesOutstanding": stock_info_json.get("sharesOutstanding"),
            "currency": stock_info_json.get("currency"),
            "ask": stock_info_json.get("ask"),
            "askSize": stock_info_json.get("askSize"),
            "previousClose": stock_info_json.get("previousClose"),
            "market": stock_info_json.get("market"),
            "marketCap": stock_info_json.get("marketCap"),
            "fiftyDayAverage": stock_info_json.get("fiftyDayAverage"),
            "fiftyTwoWeekHigh": stock_info_json.get("fiftyTwoWeekHigh"),
            "fiftyTwoWeekLow": stock_info_json.get("fiftyTwoWeekLow"),
            "boardRisk": stock_info_json.get("boardRisk"),
            "returnOnEquity": stock_info_json.get("returnOnEquity"),
            "grossProfits": to_millions(stock_info_json.get("grossProfis")),
            "totalEarnings": to_millions(stock_info_json.get("totalEarnings")),
            "totalDebt": to_millions(stock_info_json.get("totalDebt")),
            "totalCash": to_millions(stock_info_json.get("totalCash")),
            "ebitda": to_pct(stock_info_json.get("ebitda")),
        })

    return pd.DataFrame(rows)

# %%
# 💰 Download dividend + yield + totals (non-breaking, robust)
log("Downloading dividend, yields, and sharesOutstanding…", "⬇️")

data = []
stocks: List[Ticker] = []
try:
    for ticker_symbol in with_progress(pruned_tickers, desc="Fetching stock details"):
        stock = get_stock(ticker_symbol)
        stocks.append(stock)
        #log(f"Downloaded {ticker_symbol}", "✅")
        #print_stock_info(stock)
except Exception as e:
    log(f"Failed to download stock information for ticker symbol '{ticker_symbol}': {e}", "❌")

log(f"Converting stock list to dataframe...")
stocks_pd = stocks_to_pd(stocks)
log(f"Sorting dataframe...")
stocks_pd.sort_values("currentDividendYield", ascending=False, inplace=True)
# Out:
# 2025-09-26 12:03:07,228 - INFO - ⬇️ Downloading dividend, yields, and sharesOutstanding…
# Fetching stock details: 100%|██████████| 46/46 [00:00<00:00, 86519.28it/s]
# 2025-09-26 12:03:07,232 - INFO - ℹ️ Converting stock list to dataframe...
# Converting stock list to DataFrame:   0%|          | 0/46 [00:00<?, ?it/s]2025-09-26 12:03:07,235 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,235 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,236 - INFO - ℹ️ called to millions with number '160238993408' and type '<class 'int'>'
# 2025-09-26 12:03:07,237 - INFO - ℹ️ called to millions with number '28280999936' and type '<class 'int'>'
# 2025-09-26 12:03:07,238 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,239 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,240 - INFO - ℹ️ called to millions with number '747837849600' and type '<class 'int'>'
# 2025-09-26 12:03:07,241 - INFO - ℹ️ called to millions with number '262574489600' and type '<class 'int'>'
# 2025-09-26 12:03:07,242 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,243 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,244 - INFO - ℹ️ called to millions with number '8743999488' and type '<class 'int'>'
# 2025-09-26 12:03:07,244 - INFO - ℹ️ called to millions with number '1070000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,245 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,245 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,246 - INFO - ℹ️ called to millions with number '62044000256' and type '<class 'int'>'
# 2025-09-26 12:03:07,247 - INFO - ℹ️ called to millions with number '13249000448' and type '<class 'int'>'
# 2025-09-26 12:03:07,249 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,251 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,251 - INFO - ℹ️ called to millions with number '3157764096' and type '<class 'int'>'
# 2025-09-26 12:03:07,252 - INFO - ℹ️ called to millions with number '17524578304' and type '<class 'int'>'
# 2025-09-26 12:03:07,252 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,253 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,253 - INFO - ℹ️ called to millions with number '10485999616' and type '<class 'int'>'
# 2025-09-26 12:03:07,254 - INFO - ℹ️ called to millions with number '2563000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,254 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,255 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,255 - INFO - ℹ️ called to millions with number '4100000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,255 - INFO - ℹ️ called to millions with number '5552000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,255 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,255 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,257 - INFO - ℹ️ called to millions with number '15310999552' and type '<class 'int'>'
# 2025-09-26 12:03:07,258 - INFO - ℹ️ called to millions with number '827000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,259 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,260 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,260 - INFO - ℹ️ called to millions with number '15520000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,260 - INFO - ℹ️ called to millions with number '3409999872' and type '<class 'int'>'
# 2025-09-26 12:03:07,263 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,263 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,263 - INFO - ℹ️ called to millions with number '151988994048' and type '<class 'int'>'
# 2025-09-26 12:03:07,263 - INFO - ℹ️ called to millions with number '10499000320' and type '<class 'int'>'
# 2025-09-26 12:03:07,263 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,266 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,266 - INFO - ℹ️ called to millions with number '18439000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,267 - INFO - ℹ️ called to millions with number '11642000384' and type '<class 'int'>'
# 2025-09-26 12:03:07,267 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,268 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,268 - INFO - ℹ️ called to millions with number '68064002048' and type '<class 'int'>'
# 2025-09-26 12:03:07,268 - INFO - ℹ️ called to millions with number '9500999680' and type '<class 'int'>'
# 2025-09-26 12:03:07,269 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,270 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,270 - INFO - ℹ️ called to millions with number '110776999936' and type '<class 'int'>'
# 2025-09-26 12:03:07,271 - INFO - ℹ️ called to millions with number '31086999552' and type '<class 'int'>'
# 2025-09-26 12:03:07,271 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,272 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,272 - INFO - ℹ️ called to millions with number '50988998656' and type '<class 'int'>'
# 2025-09-26 12:03:07,273 - INFO - ℹ️ called to millions with number '13603000320' and type '<class 'int'>'
# 2025-09-26 12:03:07,274 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,275 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,275 - INFO - ℹ️ called to millions with number '18674999296' and type '<class 'int'>'
# 2025-09-26 12:03:07,276 - INFO - ℹ️ called to millions with number '509000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,276 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,277 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,277 - INFO - ℹ️ called to millions with number '101528002560' and type '<class 'int'>'
# 2025-09-26 12:03:07,280 - INFO - ℹ️ called to millions with number '9687000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,281 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,282 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,282 - INFO - ℹ️ called to millions with number '69319000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,283 - INFO - ℹ️ called to millions with number '22172999680' and type '<class 'int'>'
# 2025-09-26 12:03:07,283 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,283 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,284 - INFO - ℹ️ called to millions with number '174740996096' and type '<class 'int'>'
# 2025-09-26 12:03:07,284 - INFO - ℹ️ called to millions with number '3467000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,285 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,286 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,286 - INFO - ℹ️ called to millions with number '99268001792' and type '<class 'int'>'
# 2025-09-26 12:03:07,286 - INFO - ℹ️ called to millions with number '18933999616' and type '<class 'int'>'
# 2025-09-26 12:03:07,287 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,287 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,287 - INFO - ℹ️ called to millions with number '989000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,289 - INFO - ℹ️ called to millions with number '4137999872' and type '<class 'int'>'
# 2025-09-26 12:03:07,289 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,290 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,291 - INFO - ℹ️ called to millions with number '40848998400' and type '<class 'int'>'
# 2025-09-26 12:03:07,292 - INFO - ℹ️ called to millions with number '30971000832' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '18105999360' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '2737999872' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '38989000704' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '14352000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '35401998336' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '8622000128' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '50212999168' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '14296999936' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '43756998656' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number '40410001408' and type '<class 'int'>'
# 2025-09-26 12:03:07,293 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,305 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,306 - INFO - ℹ️ called to millions with number '21211000832' and type '<class 'int'>'
# 2025-09-26 12:03:07,307 - INFO - ℹ️ called to millions with number '2564000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,308 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,308 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,309 - INFO - ℹ️ called to millions with number '32810999808' and type '<class 'int'>'
# 2025-09-26 12:03:07,311 - INFO - ℹ️ called to millions with number '87000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,312 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,312 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,313 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,314 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,316 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,319 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,320 - INFO - ℹ️ called to millions with number '19519410176' and type '<class 'int'>'
# 2025-09-26 12:03:07,321 - INFO - ℹ️ called to millions with number '8973849600' and type '<class 'int'>'
# 2025-09-26 12:03:07,323 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,324 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,326 - INFO - ℹ️ called to millions with number '93188997120' and type '<class 'int'>'
# 2025-09-26 12:03:07,326 - INFO - ℹ️ called to millions with number '1728000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,327 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,327 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,329 - INFO - ℹ️ called to millions with number '4163057920' and type '<class 'int'>'
# 2025-09-26 12:03:07,329 - INFO - ℹ️ called to millions with number '451001984' and type '<class 'int'>'
# 2025-09-26 12:03:07,330 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,331 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,336 - INFO - ℹ️ called to millions with number '13701999616' and type '<class 'int'>'
# 2025-09-26 12:03:07,338 - INFO - ℹ️ called to millions with number '3747000064' and type '<class 'int'>'
# Converting stock list to DataFrame:  72%|███████▏  | 33/46 [00:00<00:00, 299.95it/s]2025-09-26 12:03:07,346 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,347 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,348 - INFO - ℹ️ called to millions with number '2749199872' and type '<class 'int'>'
# 2025-09-26 12:03:07,349 - INFO - ℹ️ called to millions with number '1019600000' and type '<class 'int'>'
# 2025-09-26 12:03:07,351 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,352 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,354 - INFO - ℹ️ called to millions with number '8310600192' and type '<class 'int'>'
# 2025-09-26 12:03:07,354 - INFO - ℹ️ called to millions with number '68000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,356 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,356 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,357 - INFO - ℹ️ called to millions with number '10775000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,358 - INFO - ℹ️ called to millions with number '2871000064' and type '<class 'int'>'
# 2025-09-26 12:03:07,359 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,360 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,362 - INFO - ℹ️ called to millions with number '61575999488' and type '<class 'int'>'
# 2025-09-26 12:03:07,364 - INFO - ℹ️ called to millions with number '242000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,365 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,366 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,368 - INFO - ℹ️ called to millions with number '18460999680' and type '<class 'int'>'
# 2025-09-26 12:03:07,369 - INFO - ℹ️ called to millions with number '102000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,371 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,372 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,375 - INFO - ℹ️ called to millions with number '3749772032' and type '<class 'int'>'
# 2025-09-26 12:03:07,376 - INFO - ℹ️ called to millions with number '1418540032' and type '<class 'int'>'
# 2025-09-26 12:03:07,377 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,379 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,380 - INFO - ℹ️ called to millions with number '17838170112' and type '<class 'int'>'
# 2025-09-26 12:03:07,381 - INFO - ℹ️ called to millions with number '232983008' and type '<class 'int'>'
# 2025-09-26 12:03:07,382 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,384 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,385 - INFO - ℹ️ called to millions with number '28909000704' and type '<class 'int'>'
# 2025-09-26 12:03:07,386 - INFO - ℹ️ called to millions with number '6286000128' and type '<class 'int'>'
# 2025-09-26 12:03:07,387 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,388 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,389 - INFO - ℹ️ called to millions with number '3647674880' and type '<class 'int'>'
# 2025-09-26 12:03:07,390 - INFO - ℹ️ called to millions with number '117613000' and type '<class 'int'>'
# 2025-09-26 12:03:07,390 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,392 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,393 - INFO - ℹ️ called to millions with number '28572000256' and type '<class 'int'>'
# 2025-09-26 12:03:07,394 - INFO - ℹ️ called to millions with number '903000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,394 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,395 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,395 - INFO - ℹ️ called to millions with number '4389000192' and type '<class 'int'>'
# 2025-09-26 12:03:07,396 - INFO - ℹ️ called to millions with number '192000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,396 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,397 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,397 - INFO - ℹ️ called to millions with number '21504999424' and type '<class 'int'>'
# 2025-09-26 12:03:07,398 - INFO - ℹ️ called to millions with number '1504000000' and type '<class 'int'>'
# 2025-09-26 12:03:07,399 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,399 - INFO - ℹ️ called to millions with number 'None' and type '<class 'NoneType'>'
# 2025-09-26 12:03:07,400 - INFO - ℹ️ called to millions with number '20401999872' and type '<class 'int'>'
# 2025-09-26 12:03:07,401 - INFO - ℹ️ called to millions with number '4341000192' and type '<class 'int'>'
# Converting stock list to DataFrame: 100%|██████████| 46/46 [00:00<00:00, 275.55it/s]
# 2025-09-26 12:03:07,405 - INFO - ℹ️ Sorting dataframe...

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
stocks_pd
# Out:
#                                          🔍                 displayName symbol  \
# 16                   AGNC Investment Corp.                    AGNC Inv   AGNC
# 11    Petróleo Brasileiro S.A. - Petrobras                        None    PBR
# 33               The Western Union Company                        None     WU
# 12                               Vale S.A.                        Vale   VALE
# 20                         Stellantis N.V.                  Stellantis   STLA
# 40             United Parcel Service, Inc.       United Parcel Service    UPS
# 4                               Ambev S.A.                       Ambev   ABEV
# 34                    Conagra Brands, Inc.              Conagra Brands    CAG
# 36                      Energy Transfer LP                        None     ET
# 3                              Pfizer Inc.                      Pfizer    PFE
# 7                                Amcor plc                       Amcor   AMCR
# 17             Verizon Communications Inc.      Verizon Communications     VZ
# 21                                Dow Inc.                         Dow    DOW
# 26                 The Kraft Heinz Company                        None    KHC
# 13            Bristol-Myers Squibb Company                        None    BMY
# 39                    VICI Properties Inc.             VICI Properties   VICI
# 1                      Banco Bradesco S.A.              Banco Bradesco    BBD
# 37      Canadian Natural Resources Limited  Canadian Natural Resources    CNQ
# 45                      Target Corporation                      Target    TGT
# 41                   Blue Owl Capital Inc.            Blue Owl Capital    OWL
# 0                       Ford Motor Company                        None      F
# 2                              Kenvue Inc.                      Kenvue   KVUE
# 31           Permian Resources Corporation           Permian Resources     PR
# 8                                  KeyCorp                        None    KEY
# 35                                 HP Inc.                          HP    HPQ
# 27                     Kinder Morgan, Inc.               Kinder Morgan    KMI
# 23                       Merck & Co., Inc.                     Merck &    MRK
# 15                     Comcast Corporation                        None  CMCSA
# 38                 Valley National Bancorp                        None    VLY
# 28           Regions Financial Corporation           Regions Financial     RF
# 9                                AT&T Inc.                        AT&T      T
# 43                     Coterra Energy Inc.                        None   CTRA
# 29                             Gerdau S.A.                      Gerdau    GGB
# 10      Huntington Bancshares Incorporated                        None   HBAN
# 25  Telefonaktiebolaget LM Ericsson (publ)                        None   ERIC
# 14                   Keurig Dr Pepper Inc.            Keurig Dr Pepper    KDP
# 22                 Exxon Mobil Corporation                 Exxon Mobil    XOM
# 6                                Nokia Oyj                       Nokia    NOK
# 32                    Schlumberger Limited                Schlumberger    SLB
# 5                      Cenovus Energy Inc.              Cenovus Energy    CVE
# 44            Mondelez International, Inc.                    Mondelez   MDLZ
# 42            The Williams Companies, Inc.      The Williams Companies    WMB
# 18                        Novo Nordisk A/S                        None    NVO
# 24                   The Coca-Cola Company                   Coca-Cola     KO
# 19                         Infosys Limited                     Infosys   INFY
# 30                    NextEra Energy, Inc.              NextEra Energy    NEE
#
#                                      website exchange        country  \
# 16                          https://agnc.com      NMS  United States
# 11                  https://petrobras.com.br      NYQ         Brazil
# 33              https://www.westernunion.com      NYQ  United States
# 12                      https://www.vale.com      NYQ         Brazil
# 20                https://www.stellantis.com      NYQ    Netherlands
# 40                       https://www.ups.com      NYQ  United States
# 4                   https://www.ambev.com.br      NYQ         Brazil
# 34             https://www.conagrabrands.com      NYQ  United States
# 36                https://energytransfer.com      NYQ  United States
# 3                     https://www.pfizer.com      NYQ  United States
# 7                      https://www.amcor.com      NYQ    Switzerland
# 17                   https://www.verizon.com      NYQ  United States
# 21                       https://www.dow.com      NYQ  United States
# 26         https://www.kraftheinzcompany.com      NMS  United States
# 13                       https://www.bms.com      NYQ  United States
# 39            https://www.viciproperties.com      NYQ  United States
# 1                     https://banco.bradesco      NYQ         Brazil
# 37                      https://www.cnrl.com      NYQ         Canada
# 45                        https://target.com      NYQ  United States
# 41                   https://www.blueowl.com      NYQ  United States
# 0                       https://www.ford.com      NYQ  United States
# 2                     https://www.kenvue.com      NYQ  United States
# 31                https://www.permianres.com      NYQ  United States
# 8                        https://www.key.com      NYQ  United States
# 35                        https://www.hp.com      NYQ  United States
# 27              https://www.kindermorgan.com      NYQ  United States
# 23                     https://www.merck.com      NYQ  United States
# 15             https://corporate.comcast.com      NMS  United States
# 38                    https://www.valley.com      NMS  United States
# 28  https://www.regions.com/personal-banking      NYQ  United States
# 9                        https://www.att.com      NYQ  United States
# 43                   https://www.coterra.com      NYQ  United States
# 29                   https://www2.gerdau.com      NYQ         Brazil
# 10                https://www.huntington.com      NMS  United States
# 25                  https://www.ericsson.com      NMS         Sweden
# 14            https://www.keurigdrpepper.com      NMS  United States
# 22          https://corporate.exxonmobil.com      NYQ  United States
# 6                      https://www.nokia.com      NYQ        Finland
# 32                       https://www.slb.com      NYQ  United States
# 5                    https://www.cenovus.com      NYQ         Canada
# 44     https://www.mondelezinternational.com      NMS  United States
# 42                  https://www.williams.com      NYQ  United States
# 18               https://www.novonordisk.com      NYQ        Denmark
# 24          https://www.coca-colacompany.com      NYQ  United States
# 19                   https://www.infosys.com      NYQ          India
# 30             https://www.nexteraenergy.com      NYQ  United States
#
#     fiveYearAvgDividendYield  dividendRate  dividendYield  \
# 16                     13.11          1.44          14.75
# 11                     21.69          1.83          13.96
# 33                      6.77          0.94          11.93
# 12                      9.08          1.18          10.85
# 20                       NaN          0.77           8.27
# 40                      3.71          6.56           7.94
# 4                       4.40          0.18           7.64
# 34                      4.11          1.40           7.74
# 36                      8.59          1.32           7.58
# 3                       4.69          1.72           7.29
# 7                       4.56          0.51           6.40
# 17                      5.86          2.76           6.37
# 21                      5.70          1.40           6.31
# 26                      4.59          1.60           6.20
# 13                      3.71          2.48           5.71
# 39                      4.95          1.80           5.62
# 1                       4.49          0.18           5.50
# 37                      4.34          1.71           5.25
# 45                      2.56          4.56           5.23
# 41                       NaN          0.90           5.18
# 0                       5.76          0.60           5.16
# 2                        NaN          0.83           5.13
# 31                       NaN          0.60           4.38
# 8                       4.90          0.82           4.36
# 35                      3.25          1.16           4.31
# 27                      5.99          1.17           4.19
# 23                      3.02          3.24           4.18
# 15                      2.61          1.32           4.17
# 38                      4.40          0.44           4.13
# 28                      3.85          1.06           3.98
# 9                       6.74          1.11           3.92
# 43                      4.46          0.88           3.71
# 29                      7.27          0.11           3.59
# 10                      4.49          0.62           3.58
# 25                      3.25          0.29           3.58
# 14                      2.28          0.92           3.57
# 22                      4.43          3.96           3.43
# 6                       3.50          0.16           3.33
# 32                      2.27          1.14           3.30
# 5                       1.90          0.58           3.28
# 44                      2.31          2.00           3.20
# 42                      5.20          2.00           3.16
# 18                      1.51          1.73           3.08
# 24                      2.95          2.04           3.09
# 19                      2.26          0.51           3.11
# 30                      2.39          2.27           3.04
#
#     currentDividendYield lastDividendDate dividendDate exDividendDate  \
# 16                 14.75       2025-08-29   2025-10-09     2025-09-30
# 11                 13.96       2025-08-25   2025-12-30     2025-08-25
# 33                 11.93       2025-09-16   2025-09-30     2025-09-16
# 12                 10.84       2025-08-13   2025-09-10     2025-08-13
# 20                  8.27       2025-04-23   2025-05-05     2025-04-23
# 40                  7.94       2025-08-18   2025-09-04     2025-08-18
# 4                   7.83       2025-08-11   2025-10-14     2025-08-11
# 34                  7.74       2025-07-30   2025-08-28     2025-07-30
# 36                  7.58       2025-08-08   2025-08-19     2025-08-08
# 3                   7.29       2025-07-25   2025-09-02     2025-07-25
# 7                   6.40       2025-05-22   2025-09-25     2025-09-05
# 17                  6.37       2025-07-10   2025-11-03     2025-10-10
# 21                  6.31       2025-08-29   2025-09-12     2025-08-29
# 26                  6.20       2025-08-29   2025-09-26     2025-08-29
# 13                  5.71       2025-07-03   2025-11-03     2025-10-03
# 39                  5.62       2025-09-18   2025-10-09     2025-09-18
# 1                   5.50       2025-08-05   2025-11-10     2025-10-01
# 37                  5.27       2025-06-13   2025-10-03     2025-09-19
# 45                  5.23       2025-08-13   2025-12-01     2025-11-12
# 41                  5.18       2025-08-14   2025-08-28     2025-12-23
# 0                   5.16       2025-08-11   2025-09-02     2025-08-11
# 2                   5.13       2025-08-13   2025-08-27     2025-08-13
# 31                  4.38       2025-09-16   2025-09-30     2025-09-16
# 8                   4.36       2025-09-02   2025-09-15     2025-09-02
# 35                  4.32       2025-09-10   2025-10-01     2025-09-10
# 27                  4.19       2025-07-31   2025-08-15     2025-07-31
# 23                  4.18       2025-09-15   2025-10-07     2025-09-15
# 15                  4.17       2025-07-02   2025-10-22     2025-10-01
# 38                  4.13       2025-09-15   2025-10-01     2025-09-15
# 28                  3.98       2025-09-02   2025-10-01     2025-09-02
# 9                   3.92       2025-07-10   2025-08-01     2025-07-10
# 43                  3.71       2025-08-14   2025-08-28     2025-08-14
# 29                  3.59       2025-08-13   2025-08-25     2025-08-13
# 10                  3.58       2025-09-17   2025-10-01     2025-09-17
# 25                  3.57       2025-03-27   2025-04-09     2025-09-29
# 14                  3.57       2025-06-27   2025-10-10     2025-09-26
# 22                  3.43       2025-08-15   2025-09-10     2025-08-15
# 6                   3.42       2025-07-29   2025-08-12     2025-07-29
# 32                  3.30       2025-09-03   2025-10-09     2025-09-03
# 5                   3.28       2025-06-13   2025-09-29     2025-09-15
# 44                  3.20       2025-06-30   2025-10-14     2025-09-30
# 42                  3.16       2025-09-12   2025-09-29     2025-09-12
# 18                  3.09       2025-03-31   2025-08-26     2025-08-18
# 24                  3.09       2025-09-15   2025-10-01     2025-09-15
# 19                  3.08       2025-05-30   2025-07-02     2025-05-30
# 30                  3.04       2025-08-28   2025-09-15     2025-08-28
#
#     lastDividendValue  currentPrice quoteType  \
# 16              0.120          9.76    EQUITY
# 11              0.247         13.11    EQUITY
# 33              0.235          7.88    EQUITY
# 12              0.342         10.89    EQUITY
# 20              0.770          9.31    EQUITY
# 40              1.640         82.58    EQUITY
# 4               0.023          2.30    EQUITY
# 34              0.350         18.08    EQUITY
# 36              0.330         17.41    EQUITY
# 3               0.430         23.60    EQUITY
# 7               0.128          7.97    EQUITY
# 17              0.678         43.35    EQUITY
# 21              0.350         22.20    EQUITY
# 26              0.400         25.81    EQUITY
# 13              0.620         43.41    EQUITY
# 39              0.450         32.04    EQUITY
# 1               0.003          3.27    EQUITY
# 37              0.432         32.47    EQUITY
# 45              1.140         87.14    EQUITY
# 41              0.225         17.36    EQUITY
# 0               0.150         11.62    EQUITY
# 2               0.208         16.17    EQUITY
# 31              0.150         13.69    EQUITY
# 8               0.205         18.81    EQUITY
# 35              0.289         26.85    EQUITY
# 27              0.293         27.93    EQUITY
# 23              0.810         77.60    EQUITY
# 15              0.330         31.62    EQUITY
# 38              0.110         10.65    EQUITY
# 28              0.265         26.60    EQUITY
# 9               0.278         28.30    EQUITY
# 43              0.220         23.70    EQUITY
# 29              0.022          3.06    EQUITY
# 10              0.155         17.32    EQUITY
# 25              0.131          8.13    EQUITY
# 14              0.230         25.75    EQUITY
# 22              0.990        115.59    EQUITY
# 6               0.047          4.68    EQUITY
# 32              0.285         34.59    EQUITY
# 5               0.147         17.70    EQUITY
# 44              0.470         62.56    EQUITY
# 42              0.500         63.31    EQUITY
# 18              1.099         56.04    EQUITY
# 24              0.510         65.98    EQUITY
# 19              0.257         16.54    EQUITY
# 30              0.567         74.65    EQUITY
#
#                             industry  sharesOutstanding currency    ask  \
# 16                   REIT - Mortgage         1053322495      USD  10.23
# 11              Oil & Gas Integrated         3721115691      USD   0.00
# 33                   Credit Services          322967281      USD   7.96
# 12  Other Industrial Metals & Mining         4268778775      USD   0.00
# 20                Auto Manufacturers         2888724012      USD   0.00
# 40    Integrated Freight & Logistics          736042904      USD  82.74
# 4                Beverages - Brewers        15592286429      USD   2.29
# 34                    Packaged Foods          478693731      USD   0.00
# 36               Oil & Gas Midstream         3432681531      USD   0.00
# 3       Drug Manufacturers - General         5685550500      USD  23.73
# 7             Packaging & Containers         2308359941      USD   0.00
# 17                  Telecom Services         4216324808      USD   0.00
# 21                         Chemicals          708844151      USD  22.40
# 26                    Packaged Foods         1183599215      USD  25.84
# 13      Drug Manufacturers - General         2035435838      USD  43.82
# 39                REIT - Diversified         1066369778      USD   0.00
# 1                   Banks - Regional         5280641247      USD   0.00
# 37                     Oil & Gas E&P         2080596000      USD  32.82
# 45                   Discount Stores          454399148      USD   0.00
# 41                  Asset Management          651092446      USD   0.00
# 0                 Auto Manufacturers         3909008221      USD   0.00
# 2      Household & Personal Products         1919069920      USD   0.00
# 31                     Oil & Gas E&P          744304408      USD   0.00
# 8                   Banks - Regional         1096515839      USD  18.94
# 35                 Computer Hardware          934701851      USD   0.00
# 27               Oil & Gas Midstream         2222077616      USD   0.00
# 23      Drug Manufacturers - General         2497783211      USD  78.27
# 15                  Telecom Services         3682762127      USD  31.65
# 38                  Banks - Regional          559720999      USD  12.11
# 28                  Banks - Regional          892308354      USD  27.30
# 9                   Telecom Services         7150385480      USD  28.32
# 43                     Oil & Gas E&P          763139972      USD   0.00
# 29                             Steel         1271778117      USD   3.13
# 10                  Banks - Regional         1458913612      USD  18.29
# 25           Communication Equipment         3071530678      USD   8.13
# 14         Beverages - Non-Alcoholic         1358435279      USD  25.75
# 22              Oil & Gas Integrated         4263247021      USD   0.00
# 6            Communication Equipment         5379095249      USD   0.00
# 32    Oil & Gas Equipment & Services         1493878835      USD  34.73
# 5               Oil & Gas Integrated         1799751000      USD   0.00
# 44                     Confectioners         1293945412      USD  65.79
# 42               Oil & Gas Midstream         1221177427      USD   0.00
# 18      Drug Manufacturers - General         3368558040      USD   0.00
# 24         Beverages - Non-Alcoholic         4303667252      USD  66.04
# 19   Information Technology Services         4145302940      USD  16.63
# 30    Utilities - Regulated Electric         2059292588      USD  74.98
#
#     askSize  previousClose     market     marketCap  fiftyDayAverage  \
# 16        1           9.76  us_market   10280427520           9.7570
# 11      235          13.45  us_market   84078272512          12.4978
# 33       37           8.16  us_market    2544982272           8.3564
# 12      536          10.83  us_market   46762217472          10.2286
# 20      310           9.63  us_market   27945707520           9.4798
# 40        3          83.90  us_market   69992300544          88.4406
# 4      2156           2.29  us_market   36527362048           2.2642
# 34       23          18.53  us_market    8654782464          19.0298
# 36       72          17.40  us_market   59762982912          17.5140
# 3       252          24.09  us_market  134178996224          24.5680
# 7       755           7.98  us_market   18397628416           8.8672
# 17      106          43.18  us_market  182777675776          43.4516
# 21       35          23.13  us_market   15736340480          24.2036
# 26       49          26.74  us_market   30548695040          27.3114
# 13       23          44.16  us_market   88358264832          46.7202
# 39       68          31.89  us_market   34166489088          32.9448
# 1      1362           3.34  us_market   32900524032           3.0050
# 37       72          32.78  us_market   67773272064          31.1502
# 45        7          88.31  us_market   39596339200          97.9742
# 41        9          17.29  us_market   26899386368          19.0364
# 0       572          11.63  us_market   46245974016          11.4594
# 2       182          16.86  us_market   31031361536          20.4974
# 31       76          13.67  us_market   11527068672          13.6920
# 8        80          18.77  us_market   20625463296          18.5508
# 35       16          27.50  us_market   25096744960          26.9118
# 27       24          27.82  us_market   62062628864          27.1516
# 23        2          79.67  us_market  193827979264          82.4840
# 15       25          31.61  us_market  116747575296          33.2028
# 38        1          10.76  us_market    5961028608          10.0684
# 28       25          26.66  us_market   23735402496          26.2604
# 9       172          28.32  us_market  202355916800          28.5334
# 43       13          23.75  us_market   18086418432          23.9458
# 29      624           3.11  us_market    6067667456           3.0252
# 10        1          17.37  us_market   25268383744          17.0432
# 25        2           8.20  us_market   27586996224           7.7304
# 14       30          26.25  us_market   34979708928          31.2020
# 22        8         114.56  us_market  492788711424         110.5892
# 6       648           4.74  us_market   25267906560           4.3942
# 32       10          34.61  us_market   51673268224          34.5534
# 5        62          17.81  us_market   31921960960          15.8032
# 44        1          64.39  us_market   80949231616          63.8388
# 42        5          62.86  us_market   77312745472          58.4416
# 18        5          58.74  us_market  252442214400          56.3802
# 24       13          66.45  us_market  283955986432          68.6914
# 19       91          17.03  us_market   69328773120          16.9688
# 30        6          73.83  us_market  153726189568          72.6854
#
#     fiftyTwoWeekHigh  fiftyTwoWeekLow  boardRisk  returnOnEquity grossProfits  \
# 16            10.630            7.850        4.0         0.03979         None
# 11            15.340           11.030        NaN         0.18483         None
# 33            12.400            7.850        1.0         1.35322         None
# 12            12.050            8.060        NaN         0.12837         None
# 20            16.290            8.390        4.0        -0.03058         None
# 40           145.010           82.000        7.0         0.34907         None
# 4              2.640            1.760        NaN         0.16049         None
# 34            32.900           18.065        1.0         0.13214         None
# 36            21.450           14.600        NaN         0.13208         None
# 3             30.430           20.920        6.0         0.12168         None
# 7             11.480            7.900        7.0         0.06602         None
# 17            47.360           37.590        6.0         0.18454         None
# 21            55.670           20.402        7.0        -0.04739         None
# 26            36.310           25.440        8.0        -0.11637         None
# 13            63.330           42.960        5.0         0.29319         None
# 39            34.030           27.980        2.0         0.10451         None
# 1              3.410            1.840        NaN         0.12346         None
# 37            37.910           24.650        9.0         0.20605         None
# 45           161.500           86.300        4.0         0.26319         None
# 41            26.725           14.550       10.0         0.04798         None
# 0             11.990            8.440       10.0         0.07152         None
# 2             25.170           16.140        4.0         0.13564         None
# 31            16.330           10.010        4.0         0.13106         None
# 8             20.040           12.730        6.0         0.01015         None
# 35            39.800           21.210        1.0             NaN         None
# 27            31.480           21.610        9.0         0.08875         None
# 23           114.790           73.310        5.0         0.35421         None
# 15            45.310           31.030        9.0         0.24919         None
# 38            11.140            7.480        5.0         0.06327         None
# 28            27.960           17.740        5.0         0.11568         None
# 9             29.790           21.050        5.0         0.11529         None
# 43            29.950           22.460        8.0         0.11420         None
# 29             3.620            2.270        NaN         0.05977         None
# 10            18.450           11.920        7.0         0.10505         None
# 25             8.990            6.640        NaN         0.20935         None
# 14            37.820           25.670        8.0         0.06181         None
# 22           126.340           97.800        6.0         0.11831         None
# 6              5.480            3.910        NaN         0.04472         None
# 32            46.160           31.110        2.0         0.19224         None
# 5             18.610           10.230        9.0         0.09004         None
# 44            75.110           53.950        8.0         0.13546         None
# 42            63.450           44.650        6.0         0.17394         None
# 18           121.340           45.050        NaN         0.79168         None
# 24            74.380           60.620        7.0         0.42370         None
# 19            23.630           15.820        NaN         0.30365         None
# 30            86.100           61.720        6.0         0.07592         None
#
#    totalEarnings      totalDebt      totalCash        ebitda
# 16          None   69319.000064   22172.999680           NaN
# 11          None   68064.002048    9500.999680  3.319075e+10
# 33          None    2749.199872    1019.600000  9.037000e+08
# 12          None  110776.999936   31086.999552  7.161200e+10
# 20          None   40848.998400   30971.000832  2.251000e+09
# 40          None   28909.000704    6286.000128  1.149700e+10
# 4           None    3157.764096   17524.578304  2.730567e+10
# 34          None    8310.600192      68.000000  2.070200e+09
# 36          None   61575.999488     242.000000  1.471800e+10
# 3           None   62044.000256   13249.000448  2.450600e+10
# 7           None   15310.999552     827.000000  2.037000e+09
# 17          None  174740.996096    3467.000064  4.991700e+10
# 21          None   18105.999360    2737.999872  3.862000e+09
# 26          None   21211.000832    2564.000000  6.273000e+09
# 13          None   50988.998656   13603.000320  1.911500e+10
# 39          None   17838.170112     232.983008  3.636071e+09
# 1           None  747837.849600  262574.489600           NaN
# 37          None   18460.999680     102.000000  1.766800e+10
# 45          None   20401.999872    4341.000192  8.668000e+09
# 41          None    3647.674880     117.613000  1.139936e+09
# 0           None  160238.993408   28280.999936  8.551000e+09
# 2           None    8743.999488    1070.000000  3.548000e+09
# 31          None    4163.057920     451.001984  3.884155e+09
# 8           None   15520.000000    3409.999872           NaN
# 35          None   10775.000064    2871.000064  4.603000e+09
# 27          None   32810.999808      87.000000  6.721000e+09
# 23          None   35401.998336    8622.000128  2.833000e+10
# 15          None  101528.002560    9687.000064  3.821900e+10
# 38          None    3749.772032    1418.540032           NaN
# 28          None            NaN            NaN           NaN
# 9           None  151988.994048   10499.000320  4.461100e+10
# 43          None    4389.000192     192.000000  4.116000e+09
# 29          None   19519.410176    8973.849600  8.629996e+09
# 10          None   18439.000064   11642.000384           NaN
# 25          None   43756.998656   40410.001408  2.166700e+10
# 14          None   18674.999296     509.000000  4.175000e+09
# 22          None   38989.000704   14352.000000  6.238200e+10
# 6           None    4100.000000    5552.000000  2.362000e+09
# 32          None   13701.999616    3747.000064  7.959000e+09
# 5           None   10485.999616    2563.000064  8.419000e+09
# 44          None   21504.999424    1504.000000  5.861000e+09
# 42          None   28572.000256     903.000000  6.027000e+09
# 18          None   99268.001792   18933.999616  1.592610e+11
# 24          None   50212.999168   14296.999936  1.579100e+10
# 19          None     989.000000    4137.999872  4.487500e+09
# 30          None   93188.997120    1728.000000  1.464300e+10

# %%
data

# %%
# 📊 Create overview DataFrame
df = pd.DataFrame(data)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 🔄 Pivot examples for analysis
pivot_sector = df.pivot_table(
    values="Annual Net (M)",
    index="Sector",
    aggfunc="sum"
).sort_values("Annual Net (M)", ascending=False)

pivot_sector

# %%
# TODO: Remove obsolete
# 💰 Download dividend & yield info from Yahoo Finance
log("Downloading dividend info from Yahoo Finance...", "⬇️")
high_dividend_tickers = pruned_tickers[:50]
data = []
for ticker_symbol in with_progress(high_dividend_tickers, desc="Downloading stock information"):
    try:
        stock = get_stock(ticker_symbol)
        stock_info_json = stock.info
        dividends = stock.dividends

        dividend_yield = stock_info_json.get("dividendYield") or 0
        five_year_yield = stock_info_json.get("fiveYearAvgDividendYield") or 0
        currency = stock_info_json.get("currency") or "USD"
        annual_div = dividends[-252:].sum() if not dividends.empty else 0

        data.append({
            "Ticker": ticker_symbol,
            "Name": stock_info_json.get("longName"),
            "Sector": universe_df.loc[universe_df["Ticker"]==ticker_symbol, "Sector"].values[0],
            "Currency": currency,
            "Dividend Yield %": round(dividend_yield*100, 2),
            "5Y Avg Yield %": round(five_year_yield, 2),
            "Annual Dividend": round(annual_div, 2)
        })
        #log(f"Processed {ticker_symbol}", "✅")
    except Exception as e:
        log(f"Failed for {ticker_symbol}: {e}", "❌")

# %%
# TODO: Throwaway code
vym = yf.Ticker("VYM")
vym_holdings = vym.funds_holdings
top50 = vym_holdings.head(50)

universe_df = pd.DataFrame({
    "Ticker": top50["symbol"],
    "Name": top50["holdingName"],
    "Sector": "High Dividend"
})
log(f"Collected {len(universe_df)} tickers from VYM ETF", "📊")
universe_df

# %%
# TODO: Throwaway code
test_url = "https://query2.finance.yahoo.com/v1/finance/screener/predefined/saved?scrIds=day_gainers&count=5"
print(requests.get(test_url, headers={"User-Agent": "Mozilla/5.0"}).json())

# %%
# TODO: Possibly throwaway code
# 📈 Add yield % if present
if "dividendYield" in df.columns:
    df["Dividend Yield %"] = (df["dividendYield"] * 100).round(2)

if "fiveYearAvgDividendYield" in df.columns:
    df["5Y Avg Yield %"] = (df["fiveYearAvgDividendYield"] * 100).round(2)

# 🧮 Per-share dividend
if "dividendRate" in df.columns:
    df["Annual Dividend (per share)"] = df["dividendRate"].round(2)

# 🏢 Company-wide totals (USD M)
if "dividendRate" in df.columns and "sharesOutstanding" in df.columns:
    df["Annual Gross (USD M)"] = (
        df["dividendRate"] * df["sharesOutstanding"] / 1_000_000
    ).round(2)
    df["Annual Net (USD M)"] = (df["Annual Gross (USD M)"] * 0.7).round(2)

log("Final dividend overview with explicit units ready", "📈")
df

# %% [markdown]
# # 🐞 Troubleshooting

# %%
def pretty_print_json(data: dict) -> str:
    """Return JSON string with indentation and sorted keys."""
    return json.dumps(data, indent=3, sort_keys=True, default=str)

from IPython.display import JSON

def pretty_print_json_new(data: dict):
    """Display JSON with indentation in Jupyter."""
    json_str = json.dumps(data, indent=2, sort_keys=True, default=str)
    display(JSON(json.loads(json_str)))  # still collapsible & colored

# %%
# 🐞 Troubleshoot WMT, GOOG, AG
test_tickers = ["WMT", "GOOG", "AG", "BBD", "NOK", "NDA-DK.CO", "NDA-FI.HE"]

stocks: List[Ticker] = []
for ticker_symbol in test_tickers:
    stock = get_stock(ticker_symbol)
    stocks.append(stock)
    print_stock_info(stock)
stocks_pd = stocks_to_pd(stocks)
stocks_pd
# Out:
# {
#    "52WeekChange": 0.33610964,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "702 South West 8th Street",
#    "ask": 104.9,
#    "askSize": 54,
#    "auditRisk": 6,
#    "averageAnalystRating": "1.4 - Strong Buy",
#    "averageDailyVolume10Day": 15098420,
#    "averageDailyVolume3Month": 16393050,
#    "averageVolume": 16393050,
#    "averageVolume10days": 15098420,
#    "beta": 0.654,
#    "bid": 104.55,
#    "bidSize": 12,
#    "boardRisk": 7,
#    "bookValue": 11.299,
#    "city": "Bentonville",
#    "companyOfficers": [
#       {
#          "age": 58,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Mr. C. Douglas McMillon",
#          "title": "President, CEO & Director",
#          "totalPay": 6249434,
#          "unexercisedValue": 0,
#          "yearBorn": 1966
#       },
#       {
#          "age": 53,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Mr. John David Rainey Jr.",
#          "title": "Executive VP & CFO",
#          "totalPay": 3534727,
#          "unexercisedValue": 0,
#          "yearBorn": 1971
#       },
#       {
#          "age": 58,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Mr. Suresh  Kumar Ph.D.",
#          "title": "Global CTO, Chief Development Officer & Executive VP",
#          "totalPay": 3709340,
#          "unexercisedValue": 0,
#          "yearBorn": 1966
#       },
#       {
#          "age": 49,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Mr. John R. Furner",
#          "title": "Executive VP, CEO & President of Walmart US",
#          "totalPay": 4327422,
#          "unexercisedValue": 0,
#          "yearBorn": 1975
#       },
#       {
#          "age": 50,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Ms. Kathryn J. McLay",
#          "title": "Executive VP, President & CEO of Walmart International",
#          "totalPay": 4095229,
#          "unexercisedValue": 0,
#          "yearBorn": 1974
#       },
#       {
#          "age": 46,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Mr. Christopher  Nicholas",
#          "title": "Executive VP, President & CEO of Sam's Club U.S.",
#          "totalPay": 3255161,
#          "unexercisedValue": 0,
#          "yearBorn": 1978
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Ms. Stephanie  Wissink",
#          "title": "Senior Vice President of Investor Relations",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 50,
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Ms. Rachel L. Brand J.D.",
#          "title": "Executive VP of Global Governance, Chief Legal Officer & Corporate Secretary",
#          "unexercisedValue": 0,
#          "yearBorn": 1974
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Ms. Elisebeth B. Collins",
#          "title": "Executive VP, Global Chief Ethics & Compliance Officer and Special Counsel",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2025,
#          "maxAge": 1,
#          "name": "Ms. Allyson  Park",
#          "title": "Senior VP & Chief Communications Officer",
#          "unexercisedValue": 0
#       }
#    ],
#    "compensationAsOfEpochDate": 1767139200,
#    "compensationRisk": 6,
#    "corporateActions": [],
#    "country": "United States",
#    "cryptoTradeable": false,
#    "currency": "USD",
#    "currentPrice": 104.27,
#    "currentRatio": 0.792,
#    "customPriceAlertConfidence": "HIGH",
#    "dateShortInterest": 1756425600,
#    "dayHigh": 106.11,
#    "dayLow": 103.73,
#    "debtToEquity": 68.719,
#    "displayName": "Walmart",
#    "dividendDate": 1767571200,
#    "dividendRate": 0.94,
#    "dividendYield": 0.9,
#    "earningsCallTimestampEnd": 1763643600,
#    "earningsCallTimestampStart": 1763643600,
#    "earningsGrowth": 0.573,
#    "earningsQuarterlyGrowth": 0.561,
#    "earningsTimestamp": 1763641800,
#    "earningsTimestampEnd": 1763641800,
#    "earningsTimestampStart": 1763641800,
#    "ebitda": 42879000576,
#    "ebitdaMargins": 0.06186,
#    "enterpriseToEbitda": 20.877,
#    "enterpriseToRevenue": 1.291,
#    "enterpriseValue": 895204196352,
#    "epsCurrentYear": 2.60883,
#    "epsForward": 2.72,
#    "epsTrailingTwelveMonths": 2.65,
#    "esgPopulated": false,
#    "exDividendDate": 1765497600,
#    "exchange": "NYQ",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "America/New_York",
#    "exchangeTimezoneShortName": "EDT",
#    "executiveTeam": [],
#    "fiftyDayAverage": 99.0834,
#    "fiftyDayAverageChange": 5.1865997,
#    "fiftyDayAverageChangePercent": 0.0523458,
#    "fiftyTwoWeekChangePercent": 33.610962,
#    "fiftyTwoWeekHigh": 106.11,
#    "fiftyTwoWeekHighChange": -1.840004,
#    "fiftyTwoWeekHighChangePercent": -0.017340533,
#    "fiftyTwoWeekLow": 77.49,
#    "fiftyTwoWeekLowChange": 26.779999,
#    "fiftyTwoWeekLowChangePercent": 0.34559298,
#    "fiftyTwoWeekRange": "77.49 - 106.11",
#    "financialCurrency": "USD",
#    "firstTradeDateMilliseconds": 83597400000,
#    "fiveYearAvgDividendYield": 1.37,
#    "floatShares": 4354133455,
#    "forwardEps": 2.72,
#    "forwardPE": 38.334557,
#    "freeCashflow": 8344999936,
#    "fullExchangeName": "NYSE",
#    "fullTimeEmployees": 2100000,
#    "gmtOffSetMilliseconds": -14400000,
#    "governanceEpochDate": 1756684800,
#    "grossMargins": 0.2491,
#    "grossProfits": 172666994688,
#    "hasPrePostMarketData": true,
#    "heldPercentInsiders": 0.45301998,
#    "heldPercentInstitutions": 0.36099997,
#    "impliedSharesOutstanding": 7972851122,
#    "industry": "Discount Stores",
#    "industryDisp": "Discount Stores",
#    "industryKey": "discount-stores",
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1755216000,
#    "lastDividendValue": 0.235,
#    "lastFiscalYearEnd": 1738281600,
#    "lastSplitDate": 1708905600,
#    "lastSplitFactor": "3:1",
#    "longBusinessSummary": "Walmart Inc. engages in the operation of retail and wholesale stores and clubs, eCommerce websites, and mobile applications worldwide. The company operates through three segments: Walmart U.S., Walmart International, and Sam's Club. It operates supercenters, supermarkets, warehouse clubs, cash and carry stores, and discount stores under Walmart and Walmart Neighborhood Market brands; membership-only warehouse clubs; and ecommerce websites, such as walmart.com.mx, walmart.ca, flipkart.com, PhonePe and other sites. The company also offers grocery items, including dry grocery, snacks, dairy, meat, produce, deli and bakery, frozen foods, alcoholic and nonalcoholic beverages, as well as consumables, such as health and beauty aids, pet supplies, household chemicals, paper goods, and baby products; and fuel and other categories. In addition, it is involved in the provision of health and wellness products covering pharmacy, optical and hearing services, over-the-counter drugs, and protein and nutrition products; and home, hardlines, and seasonal items, including home improvement, outdoor living, gardening, furniture, apparel, jewelry, tools and power equipment, housewares, toys, and mattresses. Further, the company offers consumer electronics and accessories, software, video games, office supplies, appliances, and third-party gift cards. Additionally, it operates digital payment platforms; offers financial services and related products, including money transfers, bill payments, money orders, check cashing, prepaid access, co-branded credit cards, installment lending, and earned wage access; and markets lines of merchandise under private and licensed brands. The company was formerly known as Wal-Mart Stores, Inc. and changed its name to Walmart Inc. in February 2018. Walmart Inc. was founded in 1945 and is based in Bentonville, Arkansas.",
#    "longName": "Walmart Inc.",
#    "market": "us_market",
#    "marketCap": 831329140736,
#    "marketState": "PRE",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_313055",
#    "mostRecentQuarter": 1753920000,
#    "netIncomeToCommon": 21344000000,
#    "nextFiscalYearEnd": 1769817600,
#    "numberOfAnalystOpinions": 39,
#    "open": 103.73,
#    "operatingCashflow": 38437998592,
#    "operatingMargins": 0.04389,
#    "overallRisk": 2,
#    "payoutRatio": 0.33400002,
#    "phone": "(479) 273-4000",
#    "preMarketChange": 0.47999573,
#    "preMarketChangePercent": 0.4603834,
#    "preMarketPrice": 104.74,
#    "preMarketTime": 1758193204,
#    "previousClose": 103.42,
#    "priceEpsCurrentYear": 39.96811,
#    "priceHint": 2,
#    "priceToBook": 9.2282505,
#    "priceToSalesTrailing12Months": 1.1993444,
#    "profitMargins": 0.03079,
#    "quickRatio": 0.193,
#    "quoteSourceName": "Nasdaq Real Time Price",
#    "quoteType": "EQUITY",
#    "recommendationKey": "strong_buy",
#    "recommendationMean": 1.35714,
#    "region": "US",
#    "regularMarketChange": 0.849998,
#    "regularMarketChangePercent": 0.82189,
#    "regularMarketDayHigh": 106.11,
#    "regularMarketDayLow": 103.73,
#    "regularMarketDayRange": "103.73 - 106.11",
#    "regularMarketOpen": 103.73,
#    "regularMarketPreviousClose": 103.42,
#    "regularMarketPrice": 104.27,
#    "regularMarketTime": 1758139202,
#    "regularMarketVolume": 20799475,
#    "returnOnAssets": 0.06994,
#    "returnOnEquity": 0.23375,
#    "revenueGrowth": 0.048,
#    "revenuePerShare": 86.493,
#    "sector": "Consumer Defensive",
#    "sectorDisp": "Consumer Defensive",
#    "sectorKey": "consumer-defensive",
#    "shareHolderRightsRisk": 1,
#    "sharesOutstanding": 7972851122,
#    "sharesPercentSharesOut": 0.0049,
#    "sharesShort": 38967033,
#    "sharesShortPreviousMonthDate": 1753920000,
#    "sharesShortPriorMonth": 37079076,
#    "shortName": "Walmart Inc.",
#    "shortPercentOfFloat": 0.0049,
#    "shortRatio": 2.19,
#    "sourceInterval": 15,
#    "state": "AR",
#    "symbol": "WMT",
#    "targetHighPrice": 129.0,
#    "targetLowPrice": 64.0,
#    "targetMeanPrice": 112.82051,
#    "targetMedianPrice": 115.0,
#    "totalCash": 9431000064,
#    "totalCashPerShare": 1.183,
#    "totalDebt": 66559000576,
#    "totalRevenue": 693152972800,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 0.885,
#    "trailingAnnualDividendYield": 0.008557339,
#    "trailingEps": 2.65,
#    "trailingPE": 39.347168,
#    "trailingPegRatio": 4.0104,
#    "triggerable": true,
#    "twoHundredDayAverage": 95.63025,
#    "twoHundredDayAverageChange": 8.639748,
#    "twoHundredDayAverageChangePercent": 0.090345345,
#    "typeDisp": "Equity",
#    "volume": 20799475,
#    "website": "https://corporate.walmart.com",
#    "zip": "72716"
# }
# =======================
#
# 🔍 WMT — Walmart Inc.
# displayName: Walmart
# symbol: WMT
# website: https://corporate.walmart.com
# exchange: NYQ
# country: United States
# fiveYearAvgDividendYield: 1.37
# dividendRate: 0.94
# dividendYield: 0.9
# currentDividendYield:0.90
# lastDividendDate: 2025-08-15
# dividendDate: 2026-01-05
# exDividendDate: 2025-12-12
# lastDividendValue: 0.235
# currentPrice: 104.27
# quoteType: EQUITY
# industry: Discount Stores
# {
#    "52WeekChange": 0.5305685,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "1600 Amphitheatre Parkway",
#    "ask": 259.25,
#    "askSize": 1,
#    "averageAnalystRating": "1.5 - Buy",
#    "averageDailyVolume10Day": 23498720,
#    "averageDailyVolume3Month": 25500161,
#    "averageVolume": 25500161,
#    "averageVolume10days": 23498720,
#    "beta": 1.011,
#    "bid": 238.71,
#    "bidSize": 1,
#    "bookValue": 29.983,
#    "city": "Mountain View",
#    "companyOfficers": [
#       {
#          "age": 51,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Sundar  Pichai",
#          "title": "CEO & Director",
#          "totalPay": 10319413,
#          "unexercisedValue": 0,
#          "yearBorn": 1973
#       },
#       {
#          "age": 66,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Ruth M. Porat",
#          "title": "President & Chief Investment Officer",
#          "totalPay": 3023363,
#          "unexercisedValue": 0,
#          "yearBorn": 1958
#       },
#       {
#          "age": 51,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Dr. Lawrence Edward Page II",
#          "title": "Co-Founder & Director",
#          "totalPay": 1,
#          "unexercisedValue": 0,
#          "yearBorn": 1973
#       },
#       {
#          "age": 50,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Sergey  Brin",
#          "title": "Co-Founder & Director",
#          "totalPay": 1,
#          "unexercisedValue": 0,
#          "yearBorn": 1974
#       },
#       {
#          "age": 51,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Anat  Ashkenazi",
#          "title": "Senior VP & CFO",
#          "totalPay": 11455556,
#          "unexercisedValue": 0,
#          "yearBorn": 1973
#       },
#       {
#          "age": 63,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. J. Kent Walker",
#          "title": "President of Global Affairs, Chief Legal Officer & Company Secretary",
#          "totalPay": 3019696,
#          "unexercisedValue": 0,
#          "yearBorn": 1961
#       },
#       {
#          "age": 53,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Philipp  Schindler",
#          "title": "Senior Vice President & Chief Business Officer of Google",
#          "totalPay": 3051699,
#          "unexercisedValue": 0,
#          "yearBorn": 1971
#       },
#       {
#          "age": 49,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Amie Thuener O'Toole",
#          "title": "Corporate Controller, Chief Accounting Officer & VP",
#          "unexercisedValue": 0,
#          "yearBorn": 1975
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Ellen  West",
#          "title": "Vice President of Investor Relations",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 58,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Fiona Clare Cicconi",
#          "title": "Chief People Officer",
#          "unexercisedValue": 0,
#          "yearBorn": 1966
#       }
#    ],
#    "compensationAsOfEpochDate": 1735603200,
#    "corporateActions": [],
#    "country": "United States",
#    "cryptoTradeable": false,
#    "currency": "USD",
#    "currentPrice": 249.85,
#    "currentRatio": 1.904,
#    "customPriceAlertConfidence": "HIGH",
#    "dateShortInterest": 1756425600,
#    "dayHigh": 251.95,
#    "dayLow": 246.58,
#    "debtToEquity": 11.481,
#    "displayName": "Alphabet",
#    "dividendDate": 1757894400,
#    "dividendRate": 0.84,
#    "dividendYield": 0.34,
#    "earningsCallTimestampEnd": 1753302600,
#    "earningsCallTimestampStart": 1753302600,
#    "earningsGrowth": 0.223,
#    "earningsQuarterlyGrowth": 0.194,
#    "earningsTimestamp": 1753300800,
#    "earningsTimestampEnd": 1753300800,
#    "earningsTimestampStart": 1753300800,
#    "ebitda": 140840992768,
#    "ebitdaMargins": 0.37922,
#    "enterpriseToEbitda": 21.075,
#    "enterpriseToRevenue": 7.992,
#    "enterpriseValue": 2968205918208,
#    "epsCurrentYear": 9.94606,
#    "epsForward": 8.95,
#    "epsTrailingTwelveMonths": 9.37,
#    "esgPopulated": false,
#    "exDividendDate": 1757289600,
#    "exchange": "NMS",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "America/New_York",
#    "exchangeTimezoneShortName": "EDT",
#    "executiveTeam": [],
#    "fiftyDayAverage": 206.407,
#    "fiftyDayAverageChange": 43.44301,
#    "fiftyDayAverageChangePercent": 0.21047255,
#    "fiftyTwoWeekChangePercent": 53.056847,
#    "fiftyTwoWeekHigh": 253.23,
#    "fiftyTwoWeekHighChange": -3.3799896,
#    "fiftyTwoWeekHighChangePercent": -0.013347509,
#    "fiftyTwoWeekLow": 142.66,
#    "fiftyTwoWeekLowChange": 107.19,
#    "fiftyTwoWeekLowChangePercent": 0.7513669,
#    "fiftyTwoWeekRange": "142.66 - 253.23",
#    "financialCurrency": "USD",
#    "firstTradeDateMilliseconds": 1092922200000,
#    "floatShares": 10836465880,
#    "forwardEps": 8.95,
#    "forwardPE": 27.916203,
#    "freeCashflow": 49786499072,
#    "fullExchangeName": "NasdaqGS",
#    "fullTimeEmployees": 187103,
#    "gmtOffSetMilliseconds": -14400000,
#    "grossMargins": 0.58943003,
#    "grossProfits": 218911997952,
#    "hasPrePostMarketData": true,
#    "heldPercentInsiders": 0.0669,
#    "heldPercentInstitutions": 0.60854,
#    "impliedSharesOutstanding": 12245600256,
#    "industry": "Internet Content & Information",
#    "industryDisp": "Internet Content & Information",
#    "industryKey": "internet-content-information",
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1757289600,
#    "lastDividendValue": 0.21,
#    "lastFiscalYearEnd": 1735603200,
#    "lastSplitDate": 1658102400,
#    "lastSplitFactor": "20:1",
#    "longBusinessSummary": "Alphabet Inc. offers various products and platforms in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, including ads, Android, Chrome, devices, Gmail, Google Drive, Google Maps, Google Photos, Google Play, Search, and YouTube. It is also involved in the sale of apps and in-app purchases and digital content in the Google Play and YouTube; and devices, as well as in the provision of YouTube consumer subscription services. The Google Cloud segment offers AI infrastructure, Vertex AI platform, cybersecurity, data and analytics, and other services; Google Workspace that include cloud-based communication and collaboration tools for enterprises, such as Calendar, Gmail, Docs, Drive, and Meet; and other services for enterprise customers. The Other Bets segment sells healthcare-related and internet services. The company was incorporated in 1998 and is headquartered in Mountain View, California.",
#    "longName": "Alphabet Inc.",
#    "market": "us_market",
#    "marketCap": 3019553636352,
#    "marketState": "PRE",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_29096",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 115572998144,
#    "nextFiscalYearEnd": 1767139200,
#    "numberOfAnalystOpinions": 19,
#    "open": 251.46,
#    "operatingCashflow": 133707997184,
#    "operatingMargins": 0.32429,
#    "payoutRatio": 0.0864,
#    "phone": "650-253-0000",
#    "preMarketChange": 3.3499908,
#    "preMarketChangePercent": 1.3408008,
#    "preMarketPrice": 253.2,
#    "preMarketTime": 1758193704,
#    "previousClose": 251.42,
#    "priceEpsCurrentYear": 25.1205,
#    "priceHint": 2,
#    "priceToBook": 8.3330555,
#    "priceToSalesTrailing12Months": 8.130215,
#    "profitMargins": 0.31118,
#    "quickRatio": 1.72,
#    "quoteSourceName": "Nasdaq Real Time Price",
#    "quoteType": "EQUITY",
#    "recommendationKey": "buy",
#    "recommendationMean": 1.52308,
#    "region": "US",
#    "regularMarketChange": -1.56999,
#    "regularMarketChangePercent": -0.62445,
#    "regularMarketDayHigh": 251.95,
#    "regularMarketDayLow": 246.58,
#    "regularMarketDayRange": "246.58 - 251.95",
#    "regularMarketOpen": 251.46,
#    "regularMarketPreviousClose": 251.42,
#    "regularMarketPrice": 249.85,
#    "regularMarketTime": 1758139201,
#    "regularMarketVolume": 20304209,
#    "returnOnAssets": 0.16792,
#    "returnOnEquity": 0.34829,
#    "revenueGrowth": 0.138,
#    "revenuePerShare": 30.428,
#    "sector": "Communication Services",
#    "sectorDisp": "Communication Services",
#    "sectorKey": "communication-services",
#    "sharesOutstanding": 5430000000,
#    "sharesPercentSharesOut": 0.0026,
#    "sharesShort": 31064079,
#    "sharesShortPreviousMonthDate": 1753920000,
#    "sharesShortPriorMonth": 34145448,
#    "shortName": "Alphabet Inc.",
#    "shortRatio": 1.7,
#    "sourceInterval": 15,
#    "state": "CA",
#    "symbol": "GOOG",
#    "targetHighPrice": 285.0,
#    "targetLowPrice": 185.0,
#    "targetMeanPrice": 232.61578,
#    "targetMedianPrice": 233.0,
#    "totalCash": 95147999232,
#    "totalCashPerShare": 7.867,
#    "totalDebt": 41668001792,
#    "totalRevenue": 371399000064,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 1.01,
#    "trailingAnnualDividendYield": 0.0040171826,
#    "trailingEps": 9.37,
#    "trailingPE": 26.664888,
#    "trailingPegRatio": 1.6997,
#    "triggerable": true,
#    "twoHundredDayAverage": 183.69365,
#    "twoHundredDayAverageChange": 66.15636,
#    "twoHundredDayAverageChangePercent": 0.36014503,
#    "typeDisp": "Equity",
#    "volume": 20304209,
#    "website": "https://abc.xyz",
#    "zip": "94043"
# }
# =======================
#
# 🔍 GOOG — Alphabet Inc.
# displayName: Alphabet
# symbol: GOOG
# website: https://abc.xyz
# exchange: NMS
# country: United States
# fiveYearAvgDividendYield: None
# dividendRate: 0.84
# dividendYield: 0.34
# currentDividendYield:0.34
# lastDividendDate: 2025-09-08
# dividendDate: 2025-09-15
# exDividendDate: 2025-09-08
# lastDividendValue: 0.21
# currentPrice: 249.85
# quoteType: EQUITY
# industry: Internet Content & Information
# {
#    "52WeekChange": 0.661157,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "925 West Georgia Street",
#    "address2": "Suite 1800",
#    "ask": 10.19,
#    "askSize": 213,
#    "auditRisk": 3,
#    "averageAnalystRating": "2.7 - Hold",
#    "averageDailyVolume10Day": 23200570,
#    "averageDailyVolume3Month": 19780190,
#    "averageVolume": 19780190,
#    "averageVolume10days": 23200570,
#    "beta": 1.091,
#    "bid": 10.0,
#    "bidSize": 109,
#    "boardRisk": 3,
#    "bookValue": 5.125,
#    "city": "Vancouver",
#    "companyOfficers": [
#       {
#          "age": 64,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Keith N. Neumeyer",
#          "title": "Founder, President, CEO & Director",
#          "totalPay": 3019876,
#          "unexercisedValue": 0,
#          "yearBorn": 1960
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. David  Soares C.A., CPA, M.B.A.",
#          "title": "Chief Financial Officer",
#          "totalPay": 1129125,
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Steven C. Holmes B.Sc., M.B.A.",
#          "title": "Chief Operating Officer",
#          "totalPay": 1329108,
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Colin Bradford Bower",
#          "title": "Vice President of Operations-Mexico",
#          "totalPay": 717827,
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Michael Jarred Deal",
#          "title": "Vice-President of Metallurgy & Innovation",
#          "totalPay": 764798,
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Gonzalo Ariel Mercado",
#          "title": "Vice President of Exploration & Technical Services",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Mani  Alkhafaji",
#          "title": "VP of Corporate Development & Investor Relations",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Samir Devendra Patel L.L.B., LL.B. (Hons)",
#          "title": "General Counsel & Corporate Secretary",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Jill Anne Arias",
#          "title": "Vice President of Corporate Communications & Marketing",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. David  Smith",
#          "title": "Vice President of Human Resources",
#          "unexercisedValue": 0
#       }
#    ],
#    "compensationAsOfEpochDate": 1735603200,
#    "compensationRisk": 10,
#    "corporateActions": [],
#    "country": "Canada",
#    "cryptoTradeable": false,
#    "currency": "USD",
#    "currentPrice": 10.05,
#    "currentRatio": 3.266,
#    "customPriceAlertConfidence": "HIGH",
#    "dateShortInterest": 1756425600,
#    "dayHigh": 10.5399,
#    "dayLow": 9.94,
#    "debtToEquity": 8.081,
#    "displayName": "First Majestic Silver",
#    "dividendDate": 1757894400,
#    "dividendRate": 0.02,
#    "dividendYield": 0.2,
#    "earningsCallTimestampEnd": 1755183600,
#    "earningsCallTimestampStart": 1755183600,
#    "earningsTimestamp": 1755144000,
#    "earningsTimestampEnd": 1762432200,
#    "earningsTimestampStart": 1762432200,
#    "ebitda": 291540992,
#    "ebitdaMargins": 0.3527,
#    "enterpriseToEbitda": 17.436,
#    "enterpriseToRevenue": 6.15,
#    "enterpriseValue": 5083312640,
#    "epsCurrentYear": 0.21333,
#    "epsForward": 0.26,
#    "epsTrailingTwelveMonths": -0.01,
#    "esgPopulated": false,
#    "exDividendDate": 1756425600,
#    "exchange": "NYQ",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "America/New_York",
#    "exchangeTimezoneShortName": "EDT",
#    "executiveTeam": [],
#    "fax": "604-639-8873",
#    "fiftyDayAverage": 8.9316,
#    "fiftyDayAverageChange": 1.1184006,
#    "fiftyDayAverageChangePercent": 0.12521839,
#    "fiftyTwoWeekChangePercent": 66.1157,
#    "fiftyTwoWeekHigh": 10.9,
#    "fiftyTwoWeekHighChange": -0.8499994,
#    "fiftyTwoWeekHighChangePercent": -0.0779816,
#    "fiftyTwoWeekLow": 5.09,
#    "fiftyTwoWeekLowChange": 4.96,
#    "fiftyTwoWeekLowChangePercent": 0.9744597,
#    "fiftyTwoWeekRange": "5.09 - 10.9",
#    "financialCurrency": "USD",
#    "firstTradeDateMilliseconds": 1164724200000,
#    "floatShares": 457469688,
#    "forwardEps": 0.26,
#    "forwardPE": 38.653847,
#    "freeCashflow": 163925632,
#    "fullExchangeName": "NYSE",
#    "gmtOffSetMilliseconds": -14400000,
#    "governanceEpochDate": 1756684800,
#    "grossMargins": 0.44845,
#    "grossProfits": 370683008,
#    "hasPrePostMarketData": true,
#    "heldPercentInsiders": 0.00956,
#    "heldPercentInstitutions": 0.54886,
#    "impliedSharesOutstanding": 489665844,
#    "industry": "Silver",
#    "industryDisp": "Silver",
#    "industryKey": "silver",
#    "isEarningsDateEstimate": true,
#    "language": "en-US",
#    "lastDividendDate": 1747353600,
#    "lastDividendValue": 0.005,
#    "lastFiscalYearEnd": 1735603200,
#    "longBusinessSummary": "First Majestic Silver Corp. engages in the acquisition, exploration, development, and production of mineral properties in North America. The company explores for silver and gold deposits. Its projects include the San Dimas silver/gold mine covering an area of approximately 71,867 hectares located in Durango State, Mexico; the Santa Elena silver/gold mine that covers an area of approximately 102,244 hectares located in Sonora State, Mexico; and the La Encantada silver mine covering an area of approximately 4,076 hectares located in Coahuila State, Mexico. The company was formerly known as First Majestic Resource Corp. and changed its name to First Majestic Silver Corp. in November 2006. First Majestic Silver Corp. was incorporated in 1979 and is headquartered in Vancouver, Canada.",
#    "longName": "First Majestic Silver Corp.",
#    "market": "us_market",
#    "marketCap": 4921141760,
#    "marketState": "PRE",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_3110160",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 14741000,
#    "nextFiscalYearEnd": 1767139200,
#    "numberOfAnalystOpinions": 2,
#    "open": 10.05,
#    "operatingCashflow": 268290000,
#    "operatingMargins": 0.09435,
#    "overallRisk": 9,
#    "payoutRatio": 0.0673,
#    "phone": "604-688-3033",
#    "preMarketChange": 0.10999966,
#    "preMarketChangePercent": 1.0945239,
#    "preMarketPrice": 10.16,
#    "preMarketTime": 1758193754,
#    "previousClose": 10.37,
#    "priceEpsCurrentYear": 47.11011,
#    "priceHint": 2,
#    "priceToBook": 1.9609756,
#    "priceToSalesTrailing12Months": 5.9535103,
#    "profitMargins": 0.01783,
#    "quickRatio": 2.777,
#    "quoteSourceName": "Nasdaq Real Time Price",
#    "quoteType": "EQUITY",
#    "recommendationKey": "hold",
#    "recommendationMean": 2.66667,
#    "region": "US",
#    "regularMarketChange": -0.32,
#    "regularMarketChangePercent": -3.08582,
#    "regularMarketDayHigh": 10.5399,
#    "regularMarketDayLow": 9.94,
#    "regularMarketDayRange": "9.94 - 10.5399",
#    "regularMarketOpen": 10.05,
#    "regularMarketPreviousClose": 10.37,
#    "regularMarketPrice": 10.05,
#    "regularMarketTime": 1758139202,
#    "regularMarketVolume": 21266709,
#    "returnOnAssets": 0.01988,
#    "returnOnEquity": 0.01064,
#    "revenueGrowth": 0.94,
#    "revenuePerShare": 2.145,
#    "sector": "Basic Materials",
#    "sectorDisp": "Basic Materials",
#    "sectorKey": "basic-materials",
#    "shareHolderRightsRisk": 1,
#    "sharesOutstanding": 488551323,
#    "sharesPercentSharesOut": 0.038399998,
#    "sharesShort": 18779022,
#    "sharesShortPreviousMonthDate": 1753920000,
#    "sharesShortPriorMonth": 19613512,
#    "shortName": "First Majestic Silver Corp.",
#    "shortRatio": 1.63,
#    "sourceInterval": 15,
#    "state": "BC",
#    "symbol": "AG",
#    "targetHighPrice": 12.75,
#    "targetLowPrice": 7.5,
#    "targetMeanPrice": 10.125,
#    "targetMedianPrice": 10.125,
#    "totalCash": 466576992,
#    "totalCashPerShare": 0.955,
#    "totalDebt": 234534000,
#    "totalRevenue": 826595008,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 0.02,
#    "trailingAnnualDividendYield": 0.0019286403,
#    "trailingEps": -0.01,
#    "trailingPegRatio": null,
#    "triggerable": true,
#    "twoHundredDayAverage": 6.9958,
#    "twoHundredDayAverageChange": 3.0542002,
#    "twoHundredDayAverageChangePercent": 0.43657625,
#    "typeDisp": "Equity",
#    "volume": 20344830,
#    "website": "https://www.firstmajestic.com",
#    "zip": "V6C 3L2"
# }
# =======================
#
# 🔍 AG — First Majestic Silver Corp.
# displayName: First Majestic Silver
# symbol: AG
# website: https://www.firstmajestic.com
# exchange: NYQ
# country: Canada
# fiveYearAvgDividendYield: None
# dividendRate: 0.02
# dividendYield: 0.2
# currentDividendYield:0.20
# lastDividendDate: 2025-05-16
# dividendDate: 2025-09-15
# exDividendDate: 2025-08-29
# lastDividendValue: 0.005
# currentPrice: 10.05
# quoteType: EQUITY
# industry: Silver
# {
#    "52WeekChange": 0.20363641,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "Cidade De Deus, S/N",
#    "address2": "Vila Yara",
#    "ask": 0.0,
#    "askSize": 1792,
#    "averageDailyVolume10Day": 43252600,
#    "averageDailyVolume3Month": 34782224,
#    "averageVolume": 34782224,
#    "averageVolume10days": 43252600,
#    "beta": 0.384,
#    "bid": 3.23,
#    "bidSize": 593,
#    "bookValue": 16.456,
#    "city": "Osasco",
#    "companyOfficers": [
#       {
#          "age": 59,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Marcelo  de Araujo Noronha",
#          "title": "CEO & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1965
#       },
#       {
#          "age": 56,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Cassiano Ricardo Scarpelli",
#          "title": "CFO, Executive VP of Director & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1968
#       },
#       {
#          "age": 59,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Moacir  Nachbar Jr., Junior",
#          "title": "Executive VP, Chief Risk Officer & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1965
#       },
#       {
#          "age": 56,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Antonio Jose da Barbara",
#          "title": "Managing Executive Officer &  Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1968
#       },
#       {
#          "age": 56,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Jose Ramos Rocha Neto",
#          "title": "Executive VP & Member of the Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1968
#       },
#       {
#          "age": 63,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Joao Carlos Gomes da Silva",
#          "title": "Executive Officer & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1961
#       },
#       {
#          "age": 52,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Eurico Ramos Fabri",
#          "title": "Executive VP of Director & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1972
#       },
#       {
#          "age": 57,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Guilherme Muller Leal",
#          "title": "Executive VP & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1967
#       },
#       {
#          "age": 52,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Mr. Roberto  de Jesus Paris",
#          "title": "Executive Officer & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1972
#       },
#       {
#          "age": 64,
#          "exercisedValue": 0,
#          "maxAge": 1,
#          "name": "Ms. Walkiria Schirrmeister Marchetti",
#          "title": "Managing Executive Officer & Member of Executive Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1960
#       }
#    ],
#    "corporateActions": [],
#    "country": "Brazil",
#    "cryptoTradeable": false,
#    "currency": "USD",
#    "currentPrice": 3.31,
#    "customPriceAlertConfidence": "HIGH",
#    "dateShortInterest": 1756425600,
#    "dayHigh": 3.34,
#    "dayLow": 3.21,
#    "displayName": "Banco Bradesco",
#    "dividendDate": 1759881600,
#    "dividendRate": 0.17,
#    "dividendYield": 5.19,
#    "earningsCallTimestampEnd": 1746711000,
#    "earningsCallTimestampStart": 1746711000,
#    "earningsGrowth": 0.479,
#    "earningsQuarterlyGrowth": 0.474,
#    "earningsTimestamp": 1761741000,
#    "earningsTimestampEnd": 1761741000,
#    "earningsTimestampStart": 1761741000,
#    "ebitdaMargins": 0.0,
#    "enterpriseToRevenue": 5.931,
#    "enterpriseValue": 520761475072,
#    "epsCurrentYear": 0.40613,
#    "epsForward": 0.44,
#    "epsTrailingTwelveMonths": 0.35,
#    "esgPopulated": false,
#    "exDividendDate": 1756857600,
#    "exchange": "NYQ",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "America/New_York",
#    "exchangeTimezoneShortName": "EDT",
#    "executiveTeam": [],
#    "fiftyDayAverage": 2.9574,
#    "fiftyDayAverageChange": 0.35259986,
#    "fiftyDayAverageChangePercent": 0.1192263,
#    "fiftyTwoWeekChangePercent": 20.36364,
#    "fiftyTwoWeekHigh": 3.34,
#    "fiftyTwoWeekHighChange": -0.029999971,
#    "fiftyTwoWeekHighChangePercent": -0.008982028,
#    "fiftyTwoWeekLow": 1.84,
#    "fiftyTwoWeekLowChange": 1.4699999,
#    "fiftyTwoWeekLowChangePercent": 0.798913,
#    "fiftyTwoWeekRange": "1.84 - 3.34",
#    "financialCurrency": "BRL",
#    "firstTradeDateMilliseconds": 1028295000000,
#    "fiveYearAvgDividendYield": 4.49,
#    "floatShares": 7558861646,
#    "forwardEps": 0.44,
#    "forwardPE": 7.522727,
#    "fullExchangeName": "NYSE",
#    "fullTimeEmployees": 82147,
#    "gmtOffSetMilliseconds": -14400000,
#    "grossMargins": 0.0,
#    "grossProfits": 86491373568,
#    "hasPrePostMarketData": true,
#    "heldPercentInsiders": 3.0000001e-05,
#    "heldPercentInstitutions": 0.24138,
#    "impliedSharesOutstanding": 9823250432,
#    "industry": "Banks - Regional",
#    "industryDisp": "Banks - Regional",
#    "industryKey": "banks-regional",
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1754352000,
#    "lastDividendValue": 0.003,
#    "lastFiscalYearEnd": 1735603200,
#    "lastSplitDate": 1554076800,
#    "lastSplitFactor": "6:5",
#    "longBusinessSummary": "Banco Bradesco S.A., together with its subsidiaries, provides various banking products and services to individuals, corporates, and businesses in Brazil and internationally. The company operates through two segments, Banking and Insurance. It provides current, savings, click, and salary accounts; real estate credit, vehicle financing, payroll loans, mortgage loans, microcredit, leasing, and personal and installment credit; overdraft and agribusiness loans; debit and business cards; financial and security services; consortium products; car, personal accident, dental, travel, and life insurance; investment products; pension products; foreign currency exchange services; capitalization bonds; and internet banking services. The company was founded in 1943 and is headquartered in Osasco, Brazil.",
#    "longName": "Banco Bradesco S.A.",
#    "market": "us_market",
#    "marketCap": 31410081792,
#    "marketState": "PRE",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_877263",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 20687353856,
#    "nextFiscalYearEnd": 1767139200,
#    "numberOfAnalystOpinions": 5,
#    "open": 3.21,
#    "operatingCashflow": -168044986368,
#    "operatingMargins": 0.35789,
#    "payoutRatio": 0.66580003,
#    "phone": "55 80 0704 8383",
#    "preMarketChange": 0.01999998,
#    "preMarketChangePercent": 0.60422903,
#    "preMarketPrice": 3.33,
#    "preMarketTime": 1758192331,
#    "previousClose": 3.21,
#    "priceEpsCurrentYear": 8.1501,
#    "priceHint": 4,
#    "priceToBook": 0.20114245,
#    "priceToSalesTrailing12Months": 0.3577279,
#    "profitMargins": 0.23561001,
#    "quoteSourceName": "Delayed Quote",
#    "quoteType": "EQUITY",
#    "recommendationKey": "none",
#    "region": "US",
#    "regularMarketChange": 0.0999999,
#    "regularMarketChangePercent": 3.11526,
#    "regularMarketDayHigh": 3.34,
#    "regularMarketDayLow": 3.21,
#    "regularMarketDayRange": "3.21 - 3.34",
#    "regularMarketOpen": 3.21,
#    "regularMarketPreviousClose": 3.21,
#    "regularMarketPrice": 3.31,
#    "regularMarketTime": 1758139202,
#    "regularMarketVolume": 65159217,
#    "returnOnAssets": 0.0101,
#    "returnOnEquity": 0.123459995,
#    "revenueGrowth": 0.209,
#    "revenuePerShare": 8.288,
#    "sector": "Financial Services",
#    "sectorDisp": "Financial Services",
#    "sectorKey": "financial-services",
#    "sharesOutstanding": 5280641247,
#    "sharesPercentSharesOut": 0.0015,
#    "sharesShort": 16128392,
#    "sharesShortPreviousMonthDate": 1753920000,
#    "sharesShortPriorMonth": 26918581,
#    "shortName": "Banco Bradesco Sa",
#    "shortPercentOfFloat": 0.0031,
#    "shortRatio": 0.49,
#    "sourceInterval": 15,
#    "state": "SP",
#    "symbol": "BBD",
#    "targetHighPrice": 4.1,
#    "targetLowPrice": 2.7,
#    "targetMeanPrice": 3.24,
#    "targetMedianPrice": 3.1,
#    "totalCash": 262574489600,
#    "totalCashPerShare": 24.825,
#    "totalDebt": 747837849600,
#    "totalRevenue": 87804395520,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 1.266,
#    "trailingAnnualDividendYield": 0.39439252,
#    "trailingEps": 0.35,
#    "trailingPE": 9.457143,
#    "trailingPegRatio": 0.4841,
#    "triggerable": true,
#    "twoHundredDayAverage": 2.4838,
#    "twoHundredDayAverageChange": 0.8262,
#    "twoHundredDayAverageChangePercent": 0.3326355,
#    "typeDisp": "Equity",
#    "volume": 65159217,
#    "website": "https://banco.bradesco",
#    "zip": "06029-900"
# }
# =======================
#
# 🔍 BBD — Banco Bradesco S.A.
# displayName: Banco Bradesco
# symbol: BBD
# website: https://banco.bradesco
# exchange: NYQ
# country: Brazil
# fiveYearAvgDividendYield: 4.49
# dividendRate: 0.17
# dividendYield: 5.19
# currentDividendYield:5.14
# lastDividendDate: 2025-08-05
# dividendDate: 2025-10-08
# exDividendDate: 2025-09-03
# lastDividendValue: 0.003
# currentPrice: 3.31
# quoteType: EQUITY
# industry: Banks - Regional
# {
#    "52WeekChange": 0.105882406,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "Karakaari 7",
#    "ask": 0.0,
#    "askSize": 970,
#    "averageAnalystRating": "2.4 - Buy",
#    "averageDailyVolume10Day": 30741780,
#    "averageDailyVolume3Month": 21805970,
#    "averageVolume": 21805970,
#    "averageVolume10days": 30741780,
#    "beta": 0.626,
#    "bid": 0.0,
#    "bidSize": 526,
#    "bookValue": 3.666,
#    "city": "Espoo",
#    "companyOfficers": [
#       {
#          "age": 61,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Pekka Ilmari Lundmark M.Sc.(Eng.)",
#          "title": "Advisor",
#          "totalPay": 4274977,
#          "unexercisedValue": 0,
#          "yearBorn": 1963
#       },
#       {
#          "age": 50,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Justin  Hotard",
#          "title": "President & CEO",
#          "unexercisedValue": 0,
#          "yearBorn": 1974
#       },
#       {
#          "age": 58,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Marco  Wiren M.Sc. (Econ.)",
#          "title": "Chief Financial Officer",
#          "unexercisedValue": 0,
#          "yearBorn": 1966
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Stephan  Prosi",
#          "title": "Vice President of Corporate Controlling & Accounting",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 46,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Nishant  Batra",
#          "title": "Chief Strategy & Technology Officer",
#          "unexercisedValue": 0,
#          "yearBorn": 1978
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. David Terence Mulholland C.F.A.",
#          "title": "Head of Investor Relations",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 48,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Esa  Niinimaki",
#          "title": "CLO, Interim Chief People Officer, Corporate & Secretary to the Board",
#          "unexercisedValue": 0,
#          "yearBorn": 1976
#       },
#       {
#          "age": 48,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Louise  Fisk",
#          "title": "Chief Communications & Marketing Officer",
#          "unexercisedValue": 0,
#          "yearBorn": 1976
#       },
#       {
#          "age": 54,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Maria Rosaria Varsellona J.D., L.L.B.",
#          "title": "Executive Officer",
#          "unexercisedValue": 0,
#          "yearBorn": 1970
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Lise  Karstensen",
#          "title": "Head of Nordic&Baltic, Global Enterprise & Public Sector and Country Director of Denmark",
#          "unexercisedValue": 0
#       }
#    ],
#    "compensationAsOfEpochDate": 1735603200,
#    "corporateActions": [],
#    "country": "Finland",
#    "cryptoTradeable": false,
#    "currency": "USD",
#    "currentPrice": 4.7,
#    "currentRatio": 1.459,
#    "customPriceAlertConfidence": "HIGH",
#    "dateShortInterest": 1756425600,
#    "dayHigh": 4.765,
#    "dayLow": 4.62,
#    "debtToEquity": 20.693,
#    "displayName": "Nokia",
#    "dividendDate": 1754956800,
#    "dividendRate": 0.16,
#    "dividendYield": 3.32,
#    "earningsCallTimestampEnd": 1753345800,
#    "earningsCallTimestampStart": 1753345800,
#    "earningsTimestamp": 1761222600,
#    "earningsTimestampEnd": 1761222600,
#    "earningsTimestampStart": 1761222600,
#    "ebitda": 2361999872,
#    "ebitdaMargins": 0.122729994,
#    "enterpriseToEbitda": 10.128,
#    "enterpriseToRevenue": 1.243,
#    "enterpriseValue": 23921747968,
#    "epsCurrentYear": 0.30597,
#    "epsForward": 0.35,
#    "epsTrailingTwelveMonths": 0.19,
#    "esgPopulated": false,
#    "exDividendDate": 1753747200,
#    "exchange": "NYQ",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "America/New_York",
#    "exchangeTimezoneShortName": "EDT",
#    "executiveTeam": [],
#    "fiftyDayAverage": 4.4138,
#    "fiftyDayAverageChange": 0.28620005,
#    "fiftyDayAverageChangePercent": 0.0648421,
#    "fiftyTwoWeekChangePercent": 10.588241,
#    "fiftyTwoWeekHigh": 5.48,
#    "fiftyTwoWeekHighChange": -0.7800002,
#    "fiftyTwoWeekHighChangePercent": -0.1423358,
#    "fiftyTwoWeekLow": 3.91,
#    "fiftyTwoWeekLowChange": 0.7899997,
#    "fiftyTwoWeekLowChangePercent": 0.20204596,
#    "fiftyTwoWeekRange": "3.91 - 5.48",
#    "financialCurrency": "EUR",
#    "firstTradeDateMilliseconds": 773069400000,
#    "fiveYearAvgDividendYield": 3.5,
#    "floatShares": 4259490364,
#    "forwardEps": 0.35,
#    "forwardPE": 13.428571,
#    "freeCashflow": 1330000000,
#    "fullExchangeName": "NYSE",
#    "fullTimeEmployees": 78434,
#    "gmtOffSetMilliseconds": -14400000,
#    "grossMargins": 0.44996,
#    "grossProfits": 8659999744,
#    "hasPrePostMarketData": true,
#    "heldPercentInsiders": 0.0,
#    "heldPercentInstitutions": 0.10815,
#    "impliedSharesOutstanding": 5385560064,
#    "industry": "Communication Equipment",
#    "industryDisp": "Communication Equipment",
#    "industryKey": "communication-equipment",
#    "irWebsite": "http://www.nokia.com/global/about-nokia/investors/investors/",
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1753747200,
#    "lastDividendValue": 0.047,
#    "lastFiscalYearEnd": 1735603200,
#    "lastSplitDate": 955411200,
#    "lastSplitFactor": "4:1",
#    "longBusinessSummary": "Nokia Oyj, together with its subsidiaries, provides mobile, fixed, and cloud network solutions in North and Latin America, Greater China, India, rest of the Asia Pacific, Europe, the Middle East, and Africa. It operates in four segments: Network Infrastructure, Mobile Networks, Cloud and Network Services, and Nokia Technologies. The company offers fixed network solutions, such as fiber and copper technologies, access infrastructure, in-home Wi-Fi solutions, and cloud and virtualization services; IP network solutions, which delivers IP routing and data center networking solutions for residential, mobile, enterprise, and cloud applications; and optical networks solutions, which provides optical transport networks for metro, regional, and long-haul applications. It also provides mobile technology products and services for radio access networks and microwave radio links for transport networks; and network management solutions, as well as network planning, optimization, network deployment, and technical support services. In addition, the company offers cloud and network services, including open, secure, automated, and scalable software and solutions; and 5G core, secure autonomous networks, private wireless and industrial edge, and network APIs. Further, it licenses intellectual property, including patents, technologies, and the Nokia brand. The company serves its products and services to communications service providers, industrial enterprises, governments, digital industries, webscales and hyperscalers, licensees, and the defense sector. Nokia Oyj was founded in 1865 and is headquartered in Espoo, Finland.",
#    "longName": "Nokia Oyj",
#    "market": "us_market",
#    "marketCap": 25281744896,
#    "marketState": "PRE",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_205573",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 909000000,
#    "nextFiscalYearEnd": 1767139200,
#    "numberOfAnalystOpinions": 8,
#    "open": 4.65,
#    "operatingCashflow": 2036000000,
#    "operatingMargins": 0.03894,
#    "payoutRatio": 0.8129,
#    "phone": "358 1044 88000",
#    "preMarketChange": 0.0,
#    "preMarketChangePercent": 0.0,
#    "preMarketPrice": 4.69,
#    "preMarketTime": 1758193638,
#    "previousClose": 4.61,
#    "priceEpsCurrentYear": 15.360982,
#    "priceHint": 4,
#    "priceToBook": 1.2820513,
#    "priceToSalesTrailing12Months": 1.3136103,
#    "profitMargins": 0.053000003,
#    "quickRatio": 1.151,
#    "quoteSourceName": "Nasdaq Real Time Price",
#    "quoteType": "EQUITY",
#    "recommendationKey": "buy",
#    "recommendationMean": 2.4,
#    "region": "US",
#    "regularMarketChange": 0.0899997,
#    "regularMarketChangePercent": 1.95227,
#    "regularMarketDayHigh": 4.765,
#    "regularMarketDayLow": 4.62,
#    "regularMarketDayRange": "4.62 - 4.765",
#    "regularMarketOpen": 4.65,
#    "regularMarketPreviousClose": 4.61,
#    "regularMarketPrice": 4.7,
# ...
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1742515200,
#    "lastDividendValue": 0.94,
#    "lastFiscalYearEnd": 1735603200,
#    "longBusinessSummary": "Nordea Bank Abp offers banking products and services for individuals, families, and businesses in Sweden, Finland, Norway, Denmark, and internationally. It operates through Personal Banking, Business Banking, Large Corporates & Institutions, and Asset & Wealth Management segments. The company provides various financial services to customers through mobile banking, over the phone, online meetings, and branch offices. It also offers payments, cash management, cards, working capital management, and cards and finance solutions. In addition, the company provides financing, payment, investment banking, capital market products, and securities services; and investment, savings, and risk management solutions. Further, it offers savings products and asset management, including investment funds, discretionary management, portfolio advice, and equity trading and pension accounts; and asset-based financing through leasing, hire purchase, factoring, and sales to finance partners, such as dealers, vendors and retailers, as well as life insurance and pension products and services. Nordea Bank Abp was founded in 1820 and is headquartered in Helsinki, Finland.",
#    "longName": "Nordea Bank Abp",
#    "market": "dk_market",
#    "marketCap": 354274312192,
#    "marketState": "REGULAR",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_99505",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 4824000000,
#    "nextFiscalYearEnd": 1767139200,
#    "open": 102.4,
#    "operatingCashflow": -10197999616,
#    "operatingMargins": 0.54524,
#    "overallRisk": 1,
#    "payoutRatio": 0.6763,
#    "phone": "358 2007 0000",
#    "previousClose": 102.4,
#    "priceHint": 2,
#    "priceToBook": 11.6799555,
#    "priceToSalesTrailing12Months": 30.344696,
#    "profitMargins": 0.41542,
#    "quoteSourceName": "Free Realtime Quote",
#    "quoteType": "EQUITY",
#    "recommendationKey": "none",
#    "region": "US",
#    "regularMarketChange": 0.15000153,
#    "regularMarketChangePercent": 0.14648587,
#    "regularMarketDayHigh": 103.4,
#    "regularMarketDayLow": 102.4,
#    "regularMarketDayRange": "102.4 - 103.4",
#    "regularMarketOpen": 102.4,
#    "regularMarketPreviousClose": 102.4,
#    "regularMarketPrice": 102.55,
#    "regularMarketTime": 1758194546,
#    "regularMarketVolume": 66241,
#    "returnOnAssets": 0.0078,
#    "returnOnEquity": 0.15974,
#    "revenueGrowth": -0.013,
#    "revenuePerShare": 3.357,
#    "sector": "Financial Services",
#    "sectorDisp": "Financial Services",
#    "sectorKey": "financial-services",
#    "shareHolderRightsRisk": 1,
#    "sharesOutstanding": 3441073522,
#    "shortName": "Nordea Bank Abp",
#    "sourceInterval": 15,
#    "symbol": "NDA-DK.CO",
#    "totalCash": 63588999168,
#    "totalCashPerShare": 18.386,
#    "totalDebt": 223020007424,
#    "totalRevenue": 11674999808,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 0.94,
#    "trailingAnnualDividendYield": 0.009179687,
#    "trailingEps": 10.37,
#    "trailingPE": 9.889104,
#    "trailingPegRatio": null,
#    "triggerable": true,
#    "twoHundredDayAverage": 90.8409,
#    "twoHundredDayAverageChange": 11.709106,
#    "twoHundredDayAverageChangePercent": 0.12889686,
#    "typeDisp": "Equity",
#    "volume": 66241,
#    "website": "https://www.nordea.com",
#    "zip": "00020"
# }
# =======================
#
# 🔍 NDA-DK.CO — Nordea Bank Abp
# displayName: None
# symbol: NDA-DK.CO
# website: https://www.nordea.com
# exchange: CPH
# country: Finland
# fiveYearAvgDividendYield: 6.7
# dividendRate: 7.01
# dividendYield: 6.85
# currentDividendYield:6.84
# lastDividendDate: 2025-03-21
# dividendDate: None
# exDividendDate: 2025-03-21
# lastDividendValue: 0.94
# currentPrice: 102.55
# quoteType: EQUITY
# industry: Banks - Regional
# {
#    "52WeekChange": 0.2877226,
#    "SandP52WeekChange": 0.15519178,
#    "address1": "Satamaradankatu 5",
#    "address2": "Nordea",
#    "ask": 13.755,
#    "askSize": 0,
#    "auditRisk": 10,
#    "averageAnalystRating": "1.9 - Buy",
#    "averageDailyVolume10Day": 3623974,
#    "averageDailyVolume3Month": 3855515,
#    "averageVolume": 3855515,
#    "averageVolume10days": 3623974,
#    "beta": 0.561,
#    "bid": 13.74,
#    "bidSize": 0,
#    "boardRisk": 1,
#    "bookValue": 8.78,
#    "city": "Helsinki",
#    "companyOfficers": [
#       {
#          "age": 57,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Frank  Vang-Jensen",
#          "title": "President & Group CEO",
#          "totalPay": 3264226,
#          "unexercisedValue": 0,
#          "yearBorn": 1967
#       },
#       {
#          "age": 48,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Kirsten  Renner",
#          "title": "Head of Group Technology",
#          "unexercisedValue": 0,
#          "yearBorn": 1976
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Ilkka  Ottoila",
#          "title": "Head of Investor Relations",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 58,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Ulrika Alexandra Elisabeth Romantschuk B.Sc. (Pol.), M.Sc.Pol.",
#          "title": "Head of Group Brand, Communications & Marketing",
#          "unexercisedValue": 0,
#          "yearBorn": 1966
#       },
#       {
#          "age": 61,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Johan  Ekwall",
#          "title": "Chief of Staff",
#          "unexercisedValue": 0,
#          "yearBorn": 1963
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Holger  Otterheim",
#          "title": "Head of Group Credit Control",
#          "unexercisedValue": 0
#       },
#       {
#          "age": 59,
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Mr. Anders  Jensen",
#          "title": "Nordic Head of Digital Distribution & Partnerships",
#          "unexercisedValue": 0,
#          "yearBorn": 1965
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Kati  Tommiska",
#          "title": "Head of Communications of Finland",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Ms. Tuija  Pirttila-Back",
#          "title": "Head of Business Risk Implementation & Support - Group Functions & Senior VP",
#          "unexercisedValue": 0
#       },
#       {
#          "exercisedValue": 0,
#          "fiscalYear": 2024,
#          "maxAge": 1,
#          "name": "Henrik Bang Jespersen",
#          "title": "Head of Capital Markets Services (Cms)",
#          "unexercisedValue": 0
#       }
#    ],
#    "compensationAsOfEpochDate": 1735603200,
#    "compensationRisk": 1,
#    "corporateActions": [],
#    "country": "Finland",
#    "cryptoTradeable": false,
#    "currency": "EUR",
#    "currentPrice": 13.745,
#    "customPriceAlertConfidence": "HIGH",
#    "dayHigh": 13.85,
#    "dayLow": 13.73,
#    "dividendRate": 0.94,
#    "dividendYield": 6.84,
#    "earningsCallTimestampEnd": 1750237200,
#    "earningsCallTimestampStart": 1750237200,
#    "earningsGrowth": -0.054,
#    "earningsQuarterlyGrowth": -0.063,
#    "earningsTimestamp": 1760628600,
#    "earningsTimestampEnd": 1760628600,
#    "earningsTimestampStart": 1760628600,
#    "ebitdaMargins": 0.0,
#    "enterpriseToRevenue": 17.726,
#    "enterpriseValue": 206952169472,
#    "epsCurrentYear": 1.37938,
#    "epsForward": 1.37,
#    "epsTrailingTwelveMonths": 1.39,
#    "esgPopulated": false,
#    "exDividendDate": 1742515200,
#    "exchange": "HEL",
#    "exchangeDataDelayedBy": 0,
#    "exchangeTimezoneName": "Europe/Helsinki",
#    "exchangeTimezoneShortName": "EEST",
#    "executiveTeam": [],
#    "fiftyDayAverage": 13.0926,
#    "fiftyDayAverageChange": 0.6524,
#    "fiftyDayAverageChangePercent": 0.049829677,
#    "fiftyTwoWeekChangePercent": 28.772259,
#    "fiftyTwoWeekHigh": 13.905,
#    "fiftyTwoWeekHighChange": -0.15999985,
#    "fiftyTwoWeekHighChangePercent": -0.011506641,
#    "fiftyTwoWeekLow": 9.656,
#    "fiftyTwoWeekLowChange": 4.0889997,
#    "fiftyTwoWeekLowChangePercent": 0.42346725,
#    "fiftyTwoWeekRange": "9.656 - 13.905",
#    "financialCurrency": "EUR",
#    "firstTradeDateMilliseconds": 948787200000,
#    "fiveYearAvgDividendYield": 7.79,
#    "floatShares": 3241123232,
#    "forwardEps": 1.37,
#    "forwardPE": 10.032846,
#    "fullExchangeName": "Helsinki",
#    "fullTimeEmployees": 29844,
#    "gmtOffSetMilliseconds": 10800000,
#    "governanceEpochDate": 1756684800,
#    "grossMargins": 0.0,
#    "grossProfits": 11674999808,
#    "hasPrePostMarketData": false,
#    "heldPercentInsiders": 0.01732,
#    "heldPercentInstitutions": 0.56891996,
#    "impliedSharesOutstanding": 3465120000,
#    "industry": "Banks - Regional",
#    "industryDisp": "Banks - Regional",
#    "industryKey": "banks-regional",
#    "isEarningsDateEstimate": false,
#    "language": "en-US",
#    "lastDividendDate": 1742515200,
#    "lastDividendValue": 0.94,
#    "lastFiscalYearEnd": 1735603200,
#    "longBusinessSummary": "Nordea Bank Abp offers banking products and services for individuals, families, and businesses in Sweden, Finland, Norway, Denmark, and internationally. It operates through Personal Banking, Business Banking, Large Corporates & Institutions, and Asset & Wealth Management segments. The company provides various financial services to customers through mobile banking, over the phone, online meetings, and branch offices. It also offers payments, cash management, cards, working capital management, and cards and finance solutions. In addition, the company provides financing, payment, investment banking, capital market products, and securities services; and investment, savings, and risk management solutions. Further, it offers savings products and asset management, including investment funds, discretionary management, portfolio advice, and equity trading and pension accounts; and asset-based financing through leasing, hire purchase, factoring, and sales to finance partners, such as dealers, vendors and retailers, as well as life insurance and pension products and services. Nordea Bank Abp was founded in 1820 and is headquartered in Helsinki, Finland.",
#    "longName": "Nordea Bank Abp",
#    "market": "fi_market",
#    "marketCap": 47406219264,
#    "marketState": "REGULAR",
#    "maxAge": 86400,
#    "messageBoardId": "finmb_99505",
#    "mostRecentQuarter": 1751241600,
#    "netIncomeToCommon": 4824000000,
#    "nextFiscalYearEnd": 1767139200,
#    "numberOfAnalystOpinions": 8,
#    "open": 13.79,
#    "operatingCashflow": -10197999616,
#    "operatingMargins": 0.54524,
#    "overallRisk": 1,
#    "payoutRatio": 0.6763,
#    "phone": "358 2007 0000",
#    "previousClose": 13.74,
#    "priceEpsCurrentYear": 9.964622,
#    "priceHint": 2,
#    "priceToBook": 1.5654898,
#    "priceToSalesTrailing12Months": 4.06049,
#    "profitMargins": 0.41542,
#    "quoteSourceName": "Free Realtime Quote",
#    "quoteType": "EQUITY",
#    "recommendationKey": "buy",
#    "recommendationMean": 1.875,
#    "region": "US",
#    "regularMarketChange": 0.0050001144,
#    "regularMarketChangePercent": 0.036390934,
#    "regularMarketDayHigh": 13.85,
#    "regularMarketDayLow": 13.73,
#    "regularMarketDayRange": "13.73 - 13.85",
#    "regularMarketOpen": 13.79,
#    "regularMarketPreviousClose": 13.74,
#    "regularMarketPrice": 13.745,
#    "regularMarketTime": 1758194700,
#    "regularMarketVolume": 556134,
#    "returnOnAssets": 0.0078,
#    "returnOnEquity": 0.15974,
#    "revenueGrowth": -0.013,
#    "revenuePerShare": 3.357,
#    "sector": "Financial Services",
#    "sectorDisp": "Financial Services",
#    "sectorKey": "financial-services",
#    "shareHolderRightsRisk": 1,
#    "sharesOutstanding": 3441073522,
#    "shortName": "Nordea Bank Abp",
#    "sourceInterval": 15,
#    "symbol": "NDA-FI.HE",
#    "targetHighPrice": 16.3,
#    "targetLowPrice": 11.8,
#    "targetMeanPrice": 14.30625,
#    "targetMedianPrice": 14.9,
#    "totalCash": 63588999168,
#    "totalCashPerShare": 18.386,
#    "totalDebt": 223020007424,
#    "totalRevenue": 11674999808,
#    "tradeable": false,
#    "trailingAnnualDividendRate": 0.94,
#    "trailingAnnualDividendYield": 0.06841339,
#    "trailingEps": 1.39,
#    "trailingPE": 9.888489,
#    "trailingPegRatio": null,
#    "triggerable": true,
#    "twoHundredDayAverage": 12.19235,
#    "twoHundredDayAverageChange": 1.5526495,
#    "twoHundredDayAverageChangePercent": 0.1273462,
#    "typeDisp": "Equity",
#    "volume": 556134,
#    "website": "https://www.nordea.com",
#    "zip": "00020"
# }
# =======================
#
# 🔍 NDA-FI.HE — Nordea Bank Abp
# displayName: None
# symbol: NDA-FI.HE
# website: https://www.nordea.com
# exchange: HEL
# country: Finland
# fiveYearAvgDividendYield: 7.79
# dividendRate: 0.94
# dividendYield: 6.84
# currentDividendYield:6.84
# lastDividendDate: 2025-03-21
# dividendDate: None
# exDividendDate: 2025-03-21
# lastDividendValue: 0.94
# currentPrice: 13.745
# quoteType: EQUITY
# industry: Banks - Regional
# Converting stock list to DataFrame: 100%|██████████| 7/7 [00:00<00:00, 6998.84it/s]
#                              🔍            displayName     symbol  \
# 0                 Walmart Inc.                Walmart        WMT
# 1                Alphabet Inc.               Alphabet       GOOG
# 2  First Majestic Silver Corp.  First Majestic Silver         AG
# 3          Banco Bradesco S.A.         Banco Bradesco        BBD
# 4                    Nokia Oyj                  Nokia        NOK
# 5              Nordea Bank Abp                   None  NDA-DK.CO
# 6              Nordea Bank Abp                   None  NDA-FI.HE
#
#                          website exchange        country  \
# 0  https://corporate.walmart.com      NYQ  United States
# 1                https://abc.xyz      NMS  United States
# 2  https://www.firstmajestic.com      NYQ         Canada
# 3         https://banco.bradesco      NYQ         Brazil
# 4          https://www.nokia.com      NYQ        Finland
# 5         https://www.nordea.com      CPH        Finland
# 6         https://www.nordea.com      HEL        Finland
#
#    fiveYearAvgDividendYield  dividendRate  dividendYield  \
# 0                      1.37          0.94           0.90
# 1                       NaN          0.84           0.34
# 2                       NaN          0.02           0.20
# 3                      4.49          0.17           5.19
# 4                      3.50          0.16           3.32
# 5                      6.70          7.01           6.85
# 6                      7.79          0.94           6.84
#
#    currentDividendYield  ... currency      ask askSize  previousClose  \
# 0                  0.90  ...      USD  104.900      54         103.42
# 1                  0.34  ...      USD  259.250       1         251.42
# 2                  0.20  ...      USD   10.190     213          10.37
# 3                  5.14  ...      USD    0.000    1792           3.21
# 4                  3.40  ...      USD    0.000     970           4.61
# 5                  6.84  ...      DKK  102.650       0         102.40
# 6                  6.84  ...      EUR   13.755       0          13.74
#
#       market      marketCap fiftyDayAverage  fiftyTwoWeekHigh fiftyTwoWeekLow  \
# 0  us_market   831329140736         99.0834           106.110          77.490
# 1  us_market  3019553636352        206.4070           253.230         142.660
# 2  us_market     4921141760          8.9316            10.900           5.090
# 3  us_market    31410081792          2.9574             3.340           1.840
# 4  us_market    25281744896          4.4138             5.480           3.910
# 5  dk_market   354274312192         97.6408           103.800          72.040
# 6  fi_market    47406219264         13.0926            13.905           9.656
#
#    boardRisk
# 0        7.0
# 1        NaN
# 2        3.0
# 3        NaN
# 4        NaN
# 5        1.0
# 6        1.0
#
# [7 rows x 28 columns]

# %%
0.17/3.28
# Out:
# 0.05182926829268293
